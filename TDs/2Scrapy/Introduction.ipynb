# %% [markdown]
# # Introduction
#
# [Scrapy](https://scrapy.org/) est un framework permettant de crawler des
# sites web et d'en extraire les données de façon structurée.
#
# ## Installation
#
# [Scrapy](https://scrapy.org/) ne fait pas partie de la distribution par
# défaut de Python et doit être installé manuellement. Ici, le package est
# déjà installé grâce à Pipenv.
#
# Si vous avez besoin de l'installer dans un autre cadre.
#
# -   Avec **Pipenv** : `pipenv install scrapy==2.11.2`
#
# **Vérifiez que vous avez bien activé votre environnement virtuel Python !!**

# %%
# !which python
# Out:
# 'which' n'est pas reconnu en tant que commande interne
# ou externe, un programme ex�cutable ou un fichier de commandes.

# %%
import scrapy

# %% [markdown]
# ## Architecture
#
# [Scrapy](https://scrapy.org/) est un framework comportant plusieurs
# composants.
#
# <img src="images/architecture.png" alt="image" class="align-center" />
#
# L'ensemble du processus est contrôlé par l'**engine** (les termes anglo
# saxons ont été retenus pour un meilleur référencement dans la
# [documentation officielle](https://docs.scrapy.org/en/latest/)).
#
# Le framework est articulé avec plusieurs composants qui gèrent chacun un
# rôle différent. Nous allons les détailler.
#
# -   Les **Spiders** : permettent de naviguer sur un site et de
#     référencer les règles d'extraction de la donnée.
# -   Les **Pipelines** : font le lien entre la donnée brute et des objets
#     structurés
# -   Les **Middlewares** : permettent d'effectuer des transformations sur
#     les objets ou sur les requêtes exécutées par l'engine.
# -   Le **Scheduler** : gère l'ordre et le timing des requêtes
#     effectuées.
#
# ## Fonctionnement
#
# [Scrapy](https://scrapy.org/) est entièrement organisé autour d'un
# composant central : l'*engine*.
#
# Le rôle de l'*engine* est de contrôler le flux de données entre les
# différents composants du système.
#
# 1.  En particulier, il est chargé de récupérer les *requests* définies
#     dans les *spiders*
# 2.  Ces *requests* sont ensuite fournies au *scheduler* qui se charge de
#     leur ordonnancement
# 3.  Les *requests* sont présentées selon cet ordonnancement à
#     l'*engine*...
# 4.  ... qui les transmet au *downloader*
# 5.  Le *downloader* effectue la *request* et transmet la *response* (le
#     contenu de la page web) à l'*engine*...
# 6.  ... puis l'envoie au *spider* pour traitement
# 7.  Le *spider* génére des *items* qui sont transmis à l'*engine*
# 8.  Les *items* sont ensuite poussés dans un pipeline pour nettoyage,
#     validation et stockage
#
# Ce processus est répété jusqu'à épuisement des requêtes.
#
# [Scrapy](https://scrapy.org/) est un [framework orienté
# événements](https://en.wikipedia.org/wiki/Event-driven_architecture)
# (basé sur [Twisted](https://twistedmatrix.com/)) permettant une
# programmation asynchrone (non bloquante). C'est particulièrement
# intéressant dans les opérations de scraping, puisque **le programme
# n'attend pas le résultat d'une requête pour en lancer une autre**.
#
# En effet, lorsque l'on sollicite une ressource (requête réseau, système
# de fichier, etc.) en mode bloquant, l'exécution du programme est
# suspendue le temps que la transaction avec la ressource se termine (par
# exemple le temps qu'une page web soit complètement téléchargée).
# L'intérêt de faire des appels non bloquants, c'est que l'on peut gérer
# de multiples téléchargements en parallèle, et que le programme peut
# continuer à tourner pendant ce temps.

# %% [markdown]
# # Un scraping élémentaire
#
# Avant de rentrer dans les détails du framework, nous allons mettre en
# oeuvre un premier script permettant de récupérer l'information présente
# sur [la page web](http://evene.lefigaro.fr/citations/winston-churchill)
# recensant les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill).
#
# **Exercice**
#
# Examiner le code source de cette page avec l'inspecteur de votre
# navigateur. Identifier les éléments contenant l'information recherchée,
# ici la chaîne de caractères contenant la citation proprement dite.
#
# ## Le code source
#
# Le code utilisé est le suivant:

# %%
# %load citations_churchill_spider1.py
import scrapy


class ChurchillQuotesSpider(scrapy.Spider):
    name = "citations de Churchill"
    start_urls = ["http://evene.lefigaro.fr/citations/winston-churchill", ]

    def parse(self, response):
        for cit in response.xpath('//div[@class="figsco__quote__text"]'):
            text_value = cit.xpath('a/text()').extract_first()
            yield {'text': text_value}

# %% [markdown]
# ## Le fonctionnement
#
# Le fonctionnement est le suivant:
#
# -   On importe le module scrapy (2)
# -   et on définit une sous classe de `scrapy.Spider` (4)
# -   la variable `start_urls` contient la liste des pages à scraper (6)
# -   On redéfinit la méthode $parse$ dont la signature est définie dans
#     la classe mère (8)
# -   L'objet
#     [response](https://docs.scrapy.org/en/latest/topics/request-response.html#response-objects)
#     représente la réponse à la requête HTTP (l'attribut $text$ permet
#     d'accéder à son contenu). On recherche ensuite tous les containers
#     `<div>` identifiés dans l'exercice précédent. Ici la page est
#     particulièrement bien structurée et les citations disposent de leur
#     propre container, identifié par l'attribut `class` de valeur
#     `figsco__quote__text`. La sélection se fait par une expression
#     [XPath](https://en.wikipedia.org/wiki/XPath), un langage de
#     sélection de noeud dans un document XML (9). En langage naturel, la
#     requête pourrait se formuler : "On recherche tous les containers
#     `<div>` dont la valeur de l'attribut `class` est égal à
#     `figsco__quote__text`".
# -   Pour chaque résultat, on construit un dictionnaire dont la clé est
#     `text` et la valeur le contenu du lien `<a>`. Ce résultat est fourni
#     par un générateur ($yield$) (11).
#
# On lance le scraping depuis un terminal (attention, ici on ne lance pas la cellule du jupyter notebook mais vraiment le script contenu dans le ifchier citations_churchill_spider1.py):

# %%
# !scrapy runspider citations_churchill_spider1.py
# Out:
# 2025-01-20 11:34:27 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: scrapybot)
# 2025-01-20 11:34:27 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.2.0, parsel 1.10.0, w3lib 2.2.1, Twisted 24.11.0, Python 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)], pyOpenSSL 25.0.0 (OpenSSL 3.4.0 22 Oct 2024), cryptography 44.0.0, Platform Windows-10-10.0.26100-SP0
# 2025-01-20 11:34:27 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-01-20 11:34:27 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-01-20 11:34:27 [scrapy.extensions.telnet] INFO: Telnet Password: 071cbfe3829d9457
# 2025-01-20 11:34:27 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-01-20 11:34:27 [scrapy.crawler] INFO: Overridden settings:
# {'SPIDER_LOADER_WARN_ONLY': True}
# 2025-01-20 11:34:27 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-01-20 11:34:27 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-01-20 11:34:27 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-01-20 11:34:27 [scrapy.core.engine] INFO: Spider opened
# 2025-01-20 11:34:27 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-01-20 11:34:27 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-01-20 11:34:27 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”', 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Un conciliateur c'est quelqu'un qui nourrit un crocodile en espérant qu'il sera le dernier à être mangé.”", 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Il est une bonne chose de lire des livres de citations, car les citations lorsqu’elles sont gravées dans la mémoire vous donnent de bonnes pensées.”', 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Je suis toujours prêt à apprendre, bien que je n'aime pas toujours qu'on me donne des leçons.”", 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“C'est une belle chose d'être honnête, mais il est également important d'avoir raison.”", 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“J’ai retiré plus de choses de l’alcool que l’alcool ne m’en a retirées.”', 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Pour s'améliorer, il faut changer. Donc, pour être parfait, il faut avoir changé souvent.”", 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“On considère le chef d'entreprise comme un homme à abattre, ou une vache à traire. Peu voient en lui le cheval qui tire le char.”", 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“En Angleterre, tout est permis, sauf ce qui est interdit. En Allemagne, tout est interdit, sauf ce qui est permis. En France, tout est permis, même ce qui est interdit. En U.R.S.S., tout est interdit, même ce qui est permis.”', 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“On vit de ce que l’on obtient.\rOn construit sa vie sur ce que l’on donne.”', 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.”", 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Plus vous saurez regarder loin dans le passé, plus vous verrez loin dans le futur.”', 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“L’Angleterre s’écroule dans l’ordre, et la France se relève dans le désordre.”', 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': "“En avalant les méchantes paroles qu'on ne profère pas, on ne s'est jamais abîmé l'estomac.”", 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
#
# {'text': '“Comité : Un groupe de personnes incapables de faire quoi que ce soit par elles-mêmes qui décident collectivement que rien ne peut être fait !”', 'author': 'Winston Churchill'}
# 2025-01-20 11:34:27 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-01-20 11:34:27 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 245,
#  'downloader/request_count': 1,
#  'downloader/request_method_count/GET': 1,
#  'downloader/response_bytes': 14551,
#  'downloader/response_count': 1,
#  'downloader/response_status_count/200': 1,
#  'elapsed_time_seconds': 0.141127,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 1, 20, 10, 34, 27, 519792, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 83550,
#  'httpcompression/response_count': 1,
#  'item_scraped_count': 15,
#  'items_per_minute': None,
#  'log_count/DEBUG': 17,
#  'log_count/INFO': 10,
#  'response_received_count': 1,
#  'responses_per_minute': None,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 1, 20, 10, 34, 27, 378665, tzinfo=datetime.timezone.utc)}
# 2025-01-20 11:34:27 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On y trouve des informations sur les paramètres
# utilisés:
#
# ```
# 2018-01-10 17:21:05 [scrapy.utils.log] INFO: Scrapy 1.4.0 started (bot: scrapybot)
# 2018-01-10 17:21:05 [scrapy.utils.log] INFO: Overridden settings: {'SPIDER_LOADER_WARN_ONLY': True}
# ```

# %% [markdown]
# les
# [extensions](https://docs.scrapy.org/en/latest/topics/extensions.html)
# ...:
#
# ```
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
# 'scrapy.extensions.telnet.TelnetConsole',
# 'scrapy.extensions.logstats.LogStats']
# ```

# %% [markdown]
# [Les composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html)
# ... :
#
# ```
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
# 'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
# 'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
# 'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
# 'scrapy.downloadermiddlewares.retry.RetryMiddleware',
# 'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
# 'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
# 'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
# 'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
# 'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
# 'scrapy.downloadermiddlewares.stats.DownloaderStats']
# ```

# %% [markdown]
# Idem pour [les composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# ...:
#
# ```
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
# 'scrapy.spidermiddlewares.offsite.OffsiteMiddleware',
# 'scrapy.spidermiddlewares.referer.RefererMiddleware',
# 'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
# 'scrapy.spidermiddlewares.depth.DepthMiddleware']
# ```

# %% [markdown]
# Aucun
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# n'est activé :
#
# ```
# 2018-01-10 17:21:05 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# ```

# %% [markdown]
# **Exercice**
#
# Identifier la position des [composants middleware
# downloader](https://docs.scrapy.org/en/latest/topics/downloader-middleware.html),
# des [composants middleware
# spider](https://docs.scrapy.org/en/latest/topics/spider-middleware.html)
# et du
# [pipeline](https://docs.scrapy.org/en/latest/topics/item-pipeline.html)
# dans $l'architecture <Introduction>$
#
# L'exécution du scraping proprement dit débute :
# ```
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider opened
# 2018-01-10 17:21:05 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2018-01-10 17:21:05 [scrapy.extensions.telnet] DEBUG: Telnet console listening on 127.0.0.1:6023
# ```

# %% [markdown]
# La première URL est poussée par le scheduler:
# ```
# 2018-01-10 17:21:05 [scrapy.core.engine] DEBUG: Crawled (200) <GET http://evene.lefigaro.fr/citations/winston-churchill> (referer: None)
# ```

# %% [markdown]
# ## Les résultats
#
# Les résultats sont fournis par le générateur défini dans la méthode
# $parse$ dans un dictionnaire. Ils contiennent le texte des citations
# dans la valeur de la clé `text` :
# ```
# 2018-01-10 17:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': '“Le vice inhérent au capitalisme consiste en une répartition inégale des richesses. La vertu inhérente au socialisme consiste en une égale répartition de la misère.”'}
# 2018-01-10 17:21:05 [scrapy.core.scraper] DEBUG: Scraped from <200 http://evene.lefigaro.fr/citations/winston-churchill>
# {'text': "Faire le bien, éviter le mal, c'est ça le paradis."}
# ```

# %% [markdown]
# ## Les statistiques
#
# Une fois le scraping effectué, quelques statistiques sont affichées sur
# le terminal:
# ```
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Closing spider (finished)
# 2018-01-10 17:21:05 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 242,
# 'downloader/request_count': 1,
# 'downloader/request_method_count/GET': 1,
# 'downloader/response_bytes': 17435,
# 'downloader/response_count': 1,
# 'downloader/response_status_count/200': 1,
# 'finish_reason': 'finished',
# 'finish_time': datetime.datetime(2018, 1, 10, 16, 21, 5, 858347),
# 'item_scraped_count': 16,
# 'log_count/DEBUG': 18,
# 'log_count/INFO': 7,
# 'response_received_count': 1,
# 'scheduler/dequeued': 1,
# 'scheduler/dequeued/memory': 1,
# 'scheduler/enqueued': 1,
# 'scheduler/enqueued/memory': 1,
# 'start_time': datetime.datetime(2018, 1, 10, 16, 21, 5, 645347)}
# 2018-01-10 17:21:05 [scrapy.core.engine] INFO: Spider closed (finished)
# ```

# %% [markdown]
# On observe notamment que notre code permet de récupérer la taille de la
# page web (17435 bytes), le temps d'exécution à partir des valeurs
# `finish_time` et `start_time`, le nombre d'items scrapés (16), etc...
#
# **Exercice**
#
# Les citations extraites sont elles toutes de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) ? Il sera
# peut être nécessaire de modifier le sélecteur XPath. Nous verrons ça
# lorsque il faudra récupérer les données relative à l'auteur.

# %% [markdown]
# ## Modifier les données
#
# Il est parfois nécessaire de faire un traitement sur les données
# scrapées, pour ajouter ou retirer de l'information.
#
# **Exercice**
#
# Retirer les caractères `“` et `”` qui délimitent la citation. Ces
# caractères sont identifiés en Unicode comme [LEFT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201c/index.htm) et
# [RIGHT DOUBLE QUOTATION
# MARK](http://www.fileformat.info/info/unicode/char/201d/index.htm).
#
# Attention, ici il faut bien modifier directement le script `citations_churchill_spider1.py` et lancer dans une cellule ou votre terminal la commande utilisée précédemment : `scrapy runspider citations_churchill_spider1.py`

# %% [markdown]
# ## Plus de données
#
# Il est souvent nécessaire de récupérer plusieurs informations relatives
# à un même item. Dans cet exemple, il est judicieux d'associer à la
# citation le nom de son auteur, en allant chercher cette information au
# plus près du texte lui même.
#
# **Exercice**
#
# Examiner le code source de la page web et identifier la structuration de
# la donnée associée à l'auteur. En déduire l'expression XPath permettant
# de la récupérer. S'assurer que seules les citations de [Sir Winston
# Churchill](https://en.wikipedia.org/wiki/Winston_Churchill) sont
# extraites. Ajouter une clé `author` au dictionnaire retourné par le
# $yield$ dont la valeur est précisément la chaîne de caractères contenant
# l'auteur.
#
# Un exemple de dictionnaire retourné:
# ```
# {
#     'text': "Si deux hommes ont toujours la même opinion, l'un d'eux est de trop.",
#     'author': 'Winston Churchill'
# }
# ```

# %% [markdown]
# si vous voulez stocker les données scrapées dans un fichier vous pouvez grâce à :
# ```
# scrapy runspider citations_churchill_spider1.py -o data/citation.json -t json
# ```

# %% [markdown]
# # Votre premier projet
#
#
# Dans un premier temps vous devez créer un projet Scrapy avec la commande
# :

# %%
# !scrapy startproject monprojet
# Out:
# Error: scrapy.cfg already exists in C:\Users\owenb\Desktop\E4-DataEngineerProject\TDs\2Scrapy\monprojet

# %% [markdown]
# Cette commande va créer un dossier `monprojet` contenant les éléments
# suivants correspondant au squelette :
#
# ```
# newscrawler/
#     scrapy.cfg            # Options de déploiement
#
#     newscrawler/             # Le module Python contenant les informations
#         __init__.py
#
#         items.py          # Fichier contenant les items
#
#         middlewares.py    # Fichier contenant les middlewares
#
#         pipelines.py      # Fichier contenant les pipelines
#
#         settings.py       # Fichier contenant les paramètres du projet
#
#         spiders/          # Dossier contenant toutes les spiders
#             __init__.py
# ```

# %% [markdown]
# **Attention, à partir de maintenant vous créerez et modifierez les fichiers python dans votre projet scrapy et non pas dans les cellules jupyter qui sont là juste pour l'exemple**
#
# Pour la suite, un projet scrapy du nom de `newscrawler` est présent dans le repo pour vous guider, vous pouvez vous en inspirer pour implémenter vos propres spiders mais n'hésitez pas à explorer les méthodes que scrapy offre depuis la documentation.

# %% [markdown]
# # Votre première Spider
#
# Une Spider est une classe Scrapy qui permet de mettre en place toute
# l'architecture complexe vue dans l'introduction. Pour définir une
# spider, il vous faut hériter de la classe $scrapy.Spider$. La seule
# chose à faire est de définir la première requête à effectuer et comment
# suivre les liens. La Spider s'arrêtera lorsqu'elle aura parcouru tous
# les liens qu'on lui a demandé de suivre.
#
# Pour créer une Spider on utilise la syntaxe:

# %%
# !scrapy genspider <SPIDER_NAME> <DOMAIN_NAME>
# Out:
# < �tait inattendu.

# %% [markdown]
# Par exemple,

# %%
# !cd newscrawler && scrapy genspider lemonde lemonde.fr
# Out:
# Spider 'lemonde' already exists in module:
#   newscrawler.spiders.lemonde

# %% [markdown]
# Cette commande permet de créer une spider appelée `lemonde` pour scraper
# le domaine `lemonde.fr`. Cela crée le fichier Python
# `spiders/lemonde.py` suivant :

# %%
# %load newscrawler/newscrawler/spiders/lemonde.py
import scrapy


class LemondeSpider(scrapy.Spider):
    name = 'lemonde'
    allowed_domains = ['lemonde.fr']
    start_urls = ['http://lemonde.fr/']

    def parse(self, response):
        pass

# %% [markdown]
# Une bonne pratique pour commencer à développer une Spider est de passer
# par l'interface Shell proposée par Scrapy. Elle permet de récupérer un
# objet `Response` et de tester les méthodes de récupération des données.

# %% [markdown]
# ### ATTENTION : Les commandes scrapy shell doivent être lancées dans un terminal et non dans des cellules jupyter

# %% [markdown]
# `$ scrapy shell 'http://lemonde.fr'`

# %% [markdown]
# Pour les utilisateurs de windows il vous faut mettre des doubles quotes
# :
# ```
# scrapy shell "http://lemonde.fr"
# ```

# %% [markdown]
# Scrapy lance un kernel Python
#
# Grâce à cette interface, vous avez accès à plusieurs objets comme la
# `Response`, la `Request`, la `Spider` par exemple. Vous pouvez aussi
# exécuter `view(response)` pour afficher ce que Scrapy récupère dans un
# navigateur.
#
# Voici quelques exemples de commandes que vous pouvez faire dans le scrapy shell :
# ```
# In [1]: response
# Out[1]: <200 https://www.lemonde.fr/>
#
# In [3]: request
# Out[3]: <GET https://www.lemonde.fr/>
#
# In [4]: type(request)
# Out[4]: scrapy.http.request.Request
#
# In [5]: spider
# Out[5]: <LemondeSpider 'lemonde' at 0x1080fccc0>
#
# In [6]: type(spider)
# Out[6]: monprojet.spiders.lemonde.LeMondeSpider
# ```

# %% [markdown]
# Ici on voit que la Spider est une instance de LemondeSpider. Lorsqu'on
# lance le $scrapy shell$ scrapy va chercher dans les spiders si une
# correspond au lien passé en paramètre, si oui , il l'utilise sinon une
# $DefaultSpider$ est instanciée.
#
# ## Vos premières requêtes
#
# On peut commencer à regarder comment extraire les données de la page web
# en utilisant le langage de requêtes proposé par Scrapy. Il existe deux
# types de requêtes : les requêtes `css` et `xpath`. Les requêtes `xpath`
# sont plus complexes mais plus puissantes que les requêtes `css`. Dans le
# cadre de ce tutorial, nous allons uniquement aborder les requêtes `css`,
# elles nous suffiront pour extraire les données dont nous avons besoin
# (en interne, Scrapy transforme les requêtes `css`en requêtes `xpath`.
#
# Que ce soit les requêtes `css` ou `xpath`, elles crééent des sélecteurs
# de différents types. Quelques exemples :
#
# Pour récupérer le titre d'une page :
# ```
# In [1]: response.css('title')
# Out[1]: [<Selector xpath='descendant-or-self::title' data='<title>Le Monde.fr - Actualités et Infos'>]
# ```

# %% [markdown]
# On récupère une liste de sélecteurs correspondant à la requête `css`
# appelée. La requête précédente était unique, d'autres requêtes moins
# restrictives permettent de récupérer plusieurs résultats. Par exemple
# pour rechercher l'ensemble des liens présents sur la page, on va
# rechercher les balises HTML `<a></a>`
#
# ```
# In [5]: response.css("a")[0:10]
# Out[5]:
# [<Selector xpath='descendant-or-self::a' data='<a target="_blank" data-target="jelec-he'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/"> <div class="logo__lemonde l'>,
# <Selector xpath='descendant-or-self::a' data='<a href="https://secure.lemonde.fr/sfuse'>,
# <Selector xpath='descendant-or-self::a' data='<a href="https://abo.lemonde.fr/#xtor=CS'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/" class="Burger__right-arrow j'>,
# <Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
# <Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>]
# ```

# %% [markdown]
# Pour récupérer le texte contenu dans les balises, on passe le paramètre
# `<TAG>::text`. Par exemple :
#
# ```
# In [6]: response.css("title::text")
# Out[6]: [<Selector xpath='descendant-or-self::title/text()' data='Le Monde.fr - Actualités et Infos en Fra'>]
# ```

# %% [markdown]
# ### Exercice
#
# Comparer les résultats des deux requêtes `response.css('title')` et
# `response.css('title::text')`.
#
# Maintenant pour extraire les données des selecteurs on utilise l'une des
# deux méthodes suivantes :
# - `extract()` permet de récupérer une liste
# des données extraites de tous les sélecteurs
# - `extract_first()` permet
# de récupérer une `String` provenant du premier sélecteur de la liste.
#
#
# ```
# In [7]: response.css('title::text').extract_first()
# Out[7]: 'Le Monde.fr - Actualités et Infos en France et dans le monde'
# ```

# %% [markdown]
# On peut récupérer un attribut d'une balise avec la syntaxe
# `<TAG>::attr(<ATTRIBUTE_NAME>)` :
#
# Par exemple, les liens sont contenus dans un attribut `href`:
#
# ```
# In [9]: response.css('a::attr(href)')[0:10]
# Out[9]:
# [<Selector xpath='descendant-or-self::a/@href' data='https://journal.lemonde.fr'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='https://secure.lemonde.fr/sfuser/connexi'>,
# <Selector xpath='descendant-or-self::a/@href' data='https://abo.lemonde.fr/#xtor=CS1-454[CTA'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/'>,
# <Selector xpath='descendant-or-self::a/@href' data='#'>,
# <Selector xpath='descendant-or-self::a/@href' data='/mouvement-des-gilets-jaunes/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/carlos-ghosn/'>,
# <Selector xpath='descendant-or-self::a/@href' data='/implant-files/'>]
# ```

# %% [markdown]
# Comme vu précédemment, si on veut récupérer la liste des liens de la page on applique la méthode $extract()$
#
# ```
# In [11]: response.css('a::attr(href)').extract()[0:10]
# Out[11]:
# ['https://journal.lemonde.fr',
# '/',
# 'https://secure.lemonde.fr/sfuser/connexion',
# 'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
# '/',
# '/',
# '#',
# '/mouvement-des-gilets-jaunes/',
# '/carlos-ghosn/',
# '/implant-files/']
# ```

# %% [markdown]
# Les liens dans une page HTML sont souvent codés de manière relative par
# rapport à la page courante. La méthode de l'objet `Response` peut être
# utilisée pour recréer l'url complet.
#
# Un exemple sur le 4e élément :
# ```
# In [14]: response.urljoin(response.css('a::attr(href)').extract()[8])
# Out[14]: 'https://www.lemonde.fr/carlos-ghosn/'
# ```

# %% [markdown]
# alors que :
# ```
# In [15]: response.css('a::attr(href)').extract()[8]
# Out[15]: '/carlos-ghosn/'
# ```

# %% [markdown]
# ### Exercice :
#
# Utiliser une liste compréhension pour transformer les 10
# premiers liens relatifs récupérés par la méthode `extract()` en liens
# absolus.
#
# Le résultat doit ressembler à :
# ```
# Out[23]:
# ['https://journal.lemonde.fr',
# 'https://www.lemonde.fr/',
# 'https://secure.lemonde.fr/sfuser/connexion',
# 'https://abo.lemonde.fr/#xtor=CS1-454[CTA_LMFR]-[HEADER]-5-[Home]',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/',
# 'https://www.lemonde.fr/mouvement-des-gilets-jaunes/',
# 'https://www.lemonde.fr/carlos-ghosn/',
# 'https://www.lemonde.fr/implant-files/']
# ```

# %% [markdown]
# ## Des requêtes plus complexes
#
# On peut créer des requêtes plus complexes en utilisant à la fois la
# structuration HTML du document mais également la couche de présentation
# CSS. On utilise l'inspecteur de `Google Chrome` pour identifier le type
# et l'identifiant de la balise contenant les informations.
#
# Il y a au moins deux choses à savoir en `css` :
#
# -   Les `.` représentent les classes
# -   Les `#` représentent les id
#
# On se propose de récupérer toutes les sous-catégories de news dans la
# catégorie **Actualités**. On remarque en utilisant l'inspecteur
# d'élement de Chrome que toutes les catégories sont rangées dans une
# balise avec l'id $#nav-markup$ ensuite dans les classes $Nav__item$.
#
# A partir de cette structure HTML on peut construire la requête suivante
# pour récupérer la barre de navigation:
#
# ```
# In [19]: response.css("#nav-markup")
# Out[19]: [<Selector xpath="descendant-or-self::*[@id = 'nav-markup']" data='<ul id="nav-markup"> <li class="Nav__ite'>]
# ```

# %% [markdown]
# Ensuite pour récupérer les différentes catégories :
#
# ```
# In [24]: response.css('#nav-markup').css('.Nav__item')
# Out[24]:
# [<Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item js-burger-to-show N'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item Nav__item--home Nav'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>,
# <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="/recherc'>]
# ```

# %% [markdown]
# On veut maintenant retourner tous les liens présents dans cette
# catégorie. On remarque qu'elle apparait à la 4eme position.
# ```
# In [34]: response.css("#nav-markup .Nav__item")[3]
# Out[34]: <Selector xpath="descendant-or-self::*[@id = 'nav-markup']/descendant-or-self::*/*[@class and contains(concat(' ', normalize-space(@class), ' '), ' Nav__item ')]" data='<li class="Nav__item"> <a href="#" class'>
# ```

# %% [markdown]
# Maintenant pour récupérer tous les liens, on peut chainer les requêtes.
# On accède alors à toutes les balises $a$.
#
# ```
# In [35]: response.css("#nav-markup .Nav__item")[3].css("a")
# Out[35]:
# [<Selector xpath='descendant-or-self::a' data='<a href="#" class="js-dropdown Burger__r'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/mouvement-des-gilets-jaunes/" '>,
# <Selector xpath='descendant-or-self::a' data='<a href="/carlos-ghosn/" data-suggestion'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/implant-files/" data-suggestio'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/climat/" data-suggestion>Clima'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/affaire-khashoggi/" data-sugge'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/emmanuel-macron/" data-suggest'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/ukraine/" data-suggestion>Ukra'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/russie/" data-suggestion>Russi'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/referendum-sur-le-brexit/" dat'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/harcelement-sexuel/" data-sugg'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/actualite-en-continu/" data-su'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/international/">International<'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/politique/">Politique</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/societe/">Société</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/les-decodeurs/">Les Décodeurs<'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/sport/">Sport</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/planete/">Planète</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/sciences/">Sciences</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/campus/">M Campus</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/afrique/">Le Monde Afrique</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/pixels/">Pixels</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/actualite-medias/">Médias</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/sante/">Santé</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/big-browser/">Big Browser</a>'>,
# <Selector xpath='descendant-or-self::a' data='<a href="/disparitions/">Disparitions</a'>]
# ```

# %% [markdown]
# Et pour récupérer les titres :
# ```
# In [37]: response.css("#nav-markup .Nav__item")[3].css("a::text").extract()
# Out[37]:
# ['Actualités',
#  'Guerre au Proche-Orient',
#  'Gouvernement Barnier',
#  'Guerre en Ukraine',
#  'Élection présidentielle américaine 2024',
#  '7-Octobre, un an après',
#  'Procès des viols de Mazan',
#  'Donald Trump',
#  'Climat',
#  'Guadeloupe',
#  'Toute l’actualité en continu',
#  'International',
#  'Politique',
#  'Société',
#  'Planète',
#  'Climat',
#  'Le Monde Afrique',
#  'Les Décodeurs',
#  'Sport',
#  'Education',
#  'M Campus',
#  'Santé',
#  'Intimités',
#  'Sciences',
#  'Pixels',
#  'Disparitions',
#  'Le Fil Good',
#  'Podcasts',
#  'Le Monde & Vous']
# ```

# %% [markdown]
# Le shell Scrapy permet de définir la structure des requêtes et de
# s'assurer de la pertinence du résultat retourné. Pour automatiser le
# processus, il faut intégrer cette syntaxe au code Python des modules de
# spider définis dans la structure du projet.

# %% [markdown]
# ## Intégration des requêtes
#
# Le squelette de la classe `LeMondeSpider` généré lors de la création du
# projet doit maintenant être enrichi. Par défaut 3 attributs et une
# méthode `parse()` ont été créés :
#
# -   `name` permet d'identifier sans ambiguïté la spider dans le code.
# -   `allowed_domain` permet de filtrer les requêtes et forcer la spider
#     à rester sur une liste de domaines.
# -   `starts_urls` est la liste des urls d'où la spider va partir pour
#     commencer son scraping.
# -   `parse()` est une méthode héritée de la classe `scrapy.Spider`. Elle
#     doit être redéfinie selon les requêtes que l'on doit effectuer et
#     sera appelée sur l'ensemble des urls contenus dans la liste
#     `starts_urls`.
#
# `parse()` est une fonction `callback` qui sera appelée automatiquement
# sur chaque objet `Response` retourné par la requête. Cette fonction est
# appelée de manière asynchrone. Plusieurs requêtes peuvent ainsi être
# lancées en parallèles sans bloquer le thread principal. L'objet
# `Response` passé en paramètre est le même que celui mis à disposition
# lors de l'exécution du Scrapy Shell.

# %%
def parse(self, response):
    title = response.css('title::text').extract_first()
    all_links = {
        name: response.urljoin(url) for name, url in zip(
            response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
            response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
    }
    yield {
        "title": title,
        "all_links": all_links
    }

# %% [markdown]
# La fonction est un générateur (`yield`) et retourne un dictionnaire
# composé de deux éléments :
#
# -   Le titre de la page;
# -   La liste des liens sortants sous forme de String.
#
# Pour le moment cette spider ne parcourt que la page d'accueil, ce qui
# n'est pas très productif.

# %% [markdown]
# ## Votre premier scraper
#
# Récupérer les données sur un ensemble de pages webs nécessite d'explorer
# en profondeur la structure du site en suivant tout ou partie des liens
# rencontrés.
#
# La spider peut se `balader` sur un site assez efficacement. Il suffit de
# lui indiquer comment faire. Il faut spécifier à Scrapy de générer une
# requête vers une nouvelle page en construisant l'objet `Request`
# correspondant. Ce nouvel objet `Request` est alors inséré dans le
# scheduler de Scrapy. On peut évidemment générer plusieurs `Request`
# simultanément, correspondant par exemple, à différents liens sur la page
# courante. Ils sont insérés séquentiellement dans le scheduler.
#
# Pour cela, on modifie la méthode `parse()` de façon à ce qu'elle retourne
# un objet `Request` pour chaque nouveau lien rencontré. On associe
# également à cet objet une fonction de callback qui déterminera la
# manière dont cette nouvelle page doit être extraite.
#
# Par exemple, pour que la spider continue dans les liens des différentes
# régions (pour l'instant la fonction de callback ne fait rien) :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v2.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev2"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name: response.urljoin(url) for name, url in zip(
                response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
                response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        yield {
            "title": title,
            "all_links": all_links
        }

# %% [markdown]
# Pour lancer la spider

# %%
# !cd newscrawler && scrapy crawl lemondev2
# Out:
# 2025-01-20 11:34:28 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: newscrawler)
# 2025-01-20 11:34:28 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.2.0, parsel 1.10.0, w3lib 2.2.1, Twisted 24.11.0, Python 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)], pyOpenSSL 25.0.0 (OpenSSL 3.4.0 22 Oct 2024), cryptography 44.0.0, Platform Windows-10-10.0.26100-SP0
# 2025-01-20 11:34:28 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-01-20 11:34:28 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-01-20 11:34:28 [scrapy.extensions.telnet] INFO: Telnet Password: e17217ad605546e7
# 2025-01-20 11:34:28 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-01-20 11:34:28 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2025-01-20 11:34:28 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-01-20 11:34:28 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-01-20 11:34:28 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-01-20 11:34:28 [scrapy.core.engine] INFO: Spider opened
# 2025-01-20 11:34:28 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-01-20 11:34:28 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-01-20 11:34:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2025-01-20 11:34:29 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2025-01-20 11:34:29 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr>
#
# {'title': 'Le Monde.fr - Actualités et Infos en France et dans le monde', 'all_links': {'Actualités': 'https://www.lemonde.fr', "L'investiture de Donald Trump": 'https://www.lemonde.fr/l-investiture-de-donald-trump/', 'Guerres au Proche-Orient': 'https://www.lemonde.fr/guerre-au-proche-orient/', 'Guerre en Ukraine': 'https://www.lemonde.fr/crise-ukrainienne/', 'Gouvernement Bayrou': 'https://www.lemonde.fr/gouvernement-bayrou/', 'Incendies à Los Angeles': 'https://www.lemonde.fr/incendies-a-los-angeles/', 'Affaires de Sarkozy': 'https://www.lemonde.fr/affaires-de-sarkozy/', 'Mayotte': 'https://www.lemonde.fr/mayotte/', 'Santé': 'https://www.lemonde.fr/sante/', 'Toute l’actualité en continu': 'https://www.lemonde.fr/actualite-en-continu/', 'International': 'https://www.lemonde.fr/international/', 'Politique': 'https://www.lemonde.fr/politique/', 'Société': 'https://www.lemonde.fr/societe/', 'Planète': 'https://www.lemonde.fr/planete/', 'Climat': 'https://www.lemonde.fr/climat/', 'Le Monde Afrique': 'https://www.lemonde.fr/afrique/', 'Les Décodeurs': 'https://www.lemonde.fr/les-decodeurs/', 'Sport': 'https://www.lemonde.fr/sport/', 'Education': 'https://www.lemonde.fr/education/', 'M Campus': 'https://www.lemonde.fr/campus/', 'Intimités': 'https://www.lemonde.fr/intimites/', 'Sciences': 'https://www.lemonde.fr/sciences/', 'Pixels': 'https://www.lemonde.fr/pixels/', 'Disparitions': 'https://www.lemonde.fr/disparitions/', 'Le Fil Good': 'https://www.lemonde.fr/le-fil-good/', 'Podcasts': 'https://www.lemonde.fr/podcasts/', 'Le Monde & Vous': 'https://www.lemonde.fr/le-monde-et-vous/'}}
# 2025-01-20 11:34:29 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-01-20 11:34:29 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 440,
#  'downloader/request_count': 2,
#  'downloader/request_method_count/GET': 2,
#  'downloader/response_bytes': 92237,
#  'downloader/response_count': 2,
#  'downloader/response_status_count/200': 2,
#  'elapsed_time_seconds': 0.213537,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 1, 20, 10, 34, 29, 207284, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 347214,
#  'httpcompression/response_count': 2,
#  'item_scraped_count': 1,
#  'items_per_minute': None,
#  'log_count/DEBUG': 4,
#  'log_count/INFO': 10,
#  'response_received_count': 2,
#  'responses_per_minute': None,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 1,
#  'scheduler/dequeued/memory': 1,
#  'scheduler/enqueued': 1,
#  'scheduler/enqueued/memory': 1,
#  'start_time': datetime.datetime(2025, 1, 20, 10, 34, 28, 993747, tzinfo=datetime.timezone.utc)}
# 2025-01-20 11:34:29 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On veut ensuite *entrer* dans les liens des différentes sous-catégories
# pour récupérer les articles. Pour cela, nous créons une méthode
# `parse_category()` prend en argument un objet `Response` qui sera la
# réponse correspondant aux liens des régions. On peut comme ceci
# traverser un site en définissant des méthodes différentes en fonction du
# type de contenu.
#
# Si la structure du site est plus profonde, on peut empiler autant de
# couches que souhaité.
#
# Quand on arrive sur une page d'une sous-catégorie, on peut vouloir
# récupérer tous les éléments de la page. Pour cela, on réutilise le
# scrapy Shell pour commencer le développement de la nouvelle méthode
# d'extraction.
#
# Par exemple pour la page `https://www.lemonde.fr/international/` :
#
# ```
# scrapy shell 'https://www.lemonde.fr/international/'
# ```

# %% [markdown]
# Le fil des articles est stocké dans une balise avec la classe
# `class=river`.
#
# ```
# In [3]: response.css(".river")
# Out[3]:
# [<Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n   <section>\n      '>,
# <Selector xpath="descendant-or-self::*[@class and contains(concat(' ', normalize-space(@class), ' '), ' fleuve ')]" data='<div class="fleuve">\n</div>'>]
# ```

# %% [markdown]
# Pour récupérer chacun des articles, il faut adresser les balises
# `<article>` contenues dans le sélecteur:
#
# ```
# In [4]: response.css(".river")[0].css(".teaser")
# Out[4]:
# [<Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi mg'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>,
# <Selector xpath='descendant-or-self::article' data='<article class="grid_12 alpha enrichi">\n'>]
# ```

# %% [markdown]
# Comme précédemment, on peut empiler les sélecteurs `css` pour créer des
# requêtes plus complexes.
#
# Par exemple, pour récupérer tous les titres des différents articles :
#
# ```
# In [8]: response.css(".river")[0].css(".teaser h3::text").extract()
# Out[8]:
# ['«\xa0Le Livre noir de Gaza\xa0»\xa0: décryptage d’une entreprise d’anéantissement',
#  'Au Maroc, la rue se mobilise pour Gaza, le pouvoir maintient sa coopération avec Israël',
#  'La guerre à Gaza ravive de manière inédite le traumatisme des Palestiniens',
#  '7-Octobre\xa0: Benyamin Nétanyahou sous la menace de la justice internationale',
#  'En France, un mouvement propalestinien phagocyté par LFI',
#  'En direct, guerre au\xa0Proche-Orient\xa0: le Hezbollah dit soutenir les efforts du Liban en vue d’un cessez-le-feu',
#  'A Gaza, des destructions agricoles sans précédent qui accroissent le risque de famine',
#  'La Chine veut croire à la reprise de son économie',
#  'Comment «\xa0Le Monde\xa0» a couvert un an de guerre à Gaza',
#  'Guerre Israël-Hamas\xa0: «\xa0L’enjeu consiste à admettre que le salut ne vient jamais de la puissance, uniquement de la négociation\xa0»',
#  'En cartes\xa0: un an de destructions dans la bande de Gaza',
# ...]
# ```

# %% [markdown]
# En HTML les données sont souvent de très mauvaise qualité. Il faut
# définir des méthodes permettant de les nettoyer pour être intégrées dans
# des bases de données.
#
# Par exemple, pour supprimer tous les espaces superflus :

# %%
def clean_spaces(string_):
    if string_ is not None:
        return " ".join(string_.split())

# %% [markdown]
# Pour l'appliquer à tous les titres récupérés, on peut faire une list
# comprehension :
# ```
# In [11]: [clean_spaces(article) for article in response.css(".river")[0].css(".teaser h3::text").extract()]
#
# Out[11]: ['« Le Livre noir de Gaza » : décryptage d’une entreprise d’anéantissement',
#  'Au Maroc, la rue se mobilise pour Gaza, le pouvoir maintient sa coopération avec Israël',
#  'La guerre à Gaza ravive de manière inédite le traumatisme des Palestiniens',
#  '7-Octobre : Benyamin Nétanyahou sous la menace de la justice internationale',
#  'En France, un mouvement propalestinien phagocyté par LFI',
#  'En direct, guerre au Proche-Orient : le Hezbollah dit soutenir les efforts du Liban en vue d’un cessez-le-feu',
#  'A Gaza, des destructions agricoles sans précédent qui accroissent le risque de famine',
#  'La Chine veut croire à la reprise de son économie',
# ...
# ]
#
# ```

# %% [markdown]
# La méthode précédente est intéressante si l'on ne recherche qu'une seule
# information par article.
#
# Par contre si l'on veut récupérer d'autres caractéristiques comme
# l'image ou la description par exemple, il est plus intéressant et plus
# efficace de récupérer l'objet et d'effectuer plusieurs traitements sur
# ce dernier.
#
# Chaque objet retourné par les requêtes `css` est un selecteur avec
# lequel on peut interagir.
#
# Par exemple pour récupérer le titre, l'image et la description :
#
# ```
# In [19]: for article in response.css(".river")[0].css(".teaser"):
#     ...:     title = clean_spaces(article.css('h3::text').extract_first())
#     ...:     image = article.css('img::attr(data-src)').extract_first()
#     ...:     description = article.css('p::text').extract_first()
#     ...:     print(f"Title: {title} \nImage: {image} \nDescription: {description}\n-----")
# ```

# %% [markdown]
# ```
# Title: Le Nobel de médecine honore deux pionniers de la régulation des gènes par de tout petits ARN
# Image: https://img.lemde.fr/2024/10/07/35/0/3000/2000/110/73/60/0/6dafcf3_1728304381125-063-2176426487.jpg
# Description: Les deux lauréats américains, Victor Ambros et Gary Ruvkun, sont récompensés pour l’identification d’une voie de contrôle de l’activité des gènes par des micro-ARN, qui est présente dans toutes les cellules animales et végétales.
# -----
# Title: La position de La France insoumise sur le 7-Octobre, cause de fractures à gauche
# Image: https://img.lemde.fr/2024/10/05/0/0/5304/3536/110/73/60/0/9c38cc7_1728124287163-000-34l44a7.jpg
# Description: « 7-Octobre, un an après ». Alors que Jean-Luc Mélenchon et ses troupes ont érigé la cause palestinienne comme un axe de campagne électorale, les socialistes ont condamné le refus des « insoumis » de qualifier le Hamas de mouvement « terroriste ».
# -----
# ```

# %% [markdown]
# ## Persistence des données
#
# Pour pouvoir stocker les informations que l'on récupère en parcourant un
# site, il faut pouvoir les stocker. On utilise soit de simples
# dictionnaires Python, ou mieux des `scrapy.Item` qui sont des
# dictionnaires améliorés.
#
# Nous allons voir les deux façons de faire. On peut réécrire la méthode
# `parse_category()` pour lui faire retourner un dictionnaire
# correspondant à chaque article rencontré :

# %%
def parse_category(self, response):
    for article in response.css(".river")[0].css(".teaser"):
        title = self.clean_spaces(article.css("h3::text").extract_first())
        image = article.css("img::attr(data-src)").extract_first()
        description = article.css("p::text").extract_first()
        yield {
            "title": title,
            "image": image,
            "description": description
        }

# %% [markdown]
# Si on combine tout dans la spider :

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v3.py
import scrapy
from scrapy import Request


class LemondeSpider(scrapy.Spider):
    name = "lemondev3"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response):
        title = response.css('title::text').extract_first()
        all_links = {
            name: response.urljoin(url) for name, url in zip(
                response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
                response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)

    def parse_category(self, response):
        for article in response.css(".river")[0].css(".teaser"):
            title = self.clean_spaces(article.css("h3::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css(".txt3::text").extract_first()
            yield {
                "title": title,
                "image": image,
                "description": description
            }

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On peut maintenant lancer notre spider avec la commande suivante :
# ```
# scrapy crawl <SPIDER_NAME>
# ```

# %% [markdown]
# `scrapy crawl` permet de démarrer le processus en allant chercher la
# classe `scrapy.Spider` dont l'attribut `name` = &lt;NAME&gt;.
#
# Par exemple, pour la spider `LeMondeSpider` :

# %%
# !cd newscrawler && scrapy crawl lemondev3
# Out:
# 2025-01-20 11:34:30 [scrapy.utils.log] INFO: Scrapy 2.12.0 started (bot: newscrawler)
# 2025-01-20 11:34:30 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.11.7, cssselect 1.2.0, parsel 1.10.0, w3lib 2.2.1, Twisted 24.11.0, Python 3.10.11 (tags/v3.10.11:7d4cc5a, Apr  5 2023, 00:38:17) [MSC v.1929 64 bit (AMD64)], pyOpenSSL 25.0.0 (OpenSSL 3.4.0 22 Oct 2024), cryptography 44.0.0, Platform Windows-10-10.0.26100-SP0
# 2025-01-20 11:34:30 [scrapy.addons] INFO: Enabled addons:
# []
# 2025-01-20 11:34:30 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2025-01-20 11:34:30 [scrapy.extensions.telnet] INFO: Telnet Password: 0a33e03b04447542
# 2025-01-20 11:34:30 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.logstats.LogStats']
# 2025-01-20 11:34:30 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2025-01-20 11:34:30 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2025-01-20 11:34:30 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2025-01-20 11:34:30 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2025-01-20 11:34:30 [scrapy.core.engine] INFO: Spider opened
# 2025-01-20 11:34:30 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2025-01-20 11:34:30 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2025-01-20 11:34:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2025-01-20 11:34:30 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sport/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/climat/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/planete/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/afrique/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/politique/> (referer: https://www.lemonde.fr)
# 2025-01-20 11:34:31 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\defer.py", line 327, in iter_errback
#     yield next(it)
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 368, in __next__
#     return next(self.data)
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 368, in __next__
#     return next(self.data)
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     yield from iterable
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 379, in <genexpr>
#     return (self._set_referer(r, response) for r in result)
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     yield from iterable
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 57, in <genexpr>
#     return (r for r in result if self._filter(r, spider))
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     yield from iterable
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 54, in <genexpr>
#     return (r for r in result if self._filter(r, response, spider))
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     yield from iterable
#   File "C:\Users\owenb\Desktop\E4-DataEngineerProject\TDs\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v3.py", line 20, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\parsel\selector.py", line 135, in __getitem__
#     o = super().__getitem__(pos)
# IndexError: list index out of range
# 2025-01-20 11:34:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Comment les élèves s’orientent après le bac ? Les exemples de l’Allemagne, de la Norvège et de l’Italie', 'image': 'https://img.lemde.fr/2025/01/17/0/0/2125/1417/110/73/60/0/32a2d9c_sirius-fs-upload-1-xxbqx5ladg6g-1737109462373-le-monde-5-final.jpg', 'description': 'De la Norvège, où les bacheliers ont accès à une plateforme nationale, à l’Italie, où le système est plus direct, focus sur les dispositifs postbac dans d’autres pays d’Europe.'}
# 2025-01-20 11:34:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': 'Une école d’ingénieurs privée crée une voie de recrutement 100 % féminine', 'image': 'https://img.lemde.fr/2025/01/19/0/0/8088/5392/110/73/60/0/121eb15_sirius-fs-upload-1-1kvf2yi4x813-1737327780031-000-36u38zv.jpg', 'description': 'L’EPF Engineering School a obtenu le feu vert du ministère de l’enseignement supérieur pour offrir sur Parcoursup de manière inédite 50\xa0places supplémentaires, ainsi qu’un parcours de formation réservé aux futures bachelières.'}
# 2025-01-20 11:34:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '« Un an après, c’est tellement agréable de ne plus avoir à réfléchir à Parcoursup »', 'image': 'https://img.lemde.fr/2025/01/13/0/0/3189/2126/110/73/60/0/7c6bdf1_sirius-fs-upload-1-k20wsikodrlq-1736763708829-cgab9591.jpg', 'description': 'Depuis janvier 2024, «\xa0Le Monde\xa0» a suivi neuf jeunes aux profils variés à des dates-clés de la procédure. Aujourd’hui, ils sont tous étudiants et épanouis dans leur nouvelle vie.'}
# 2025-01-20 11:34:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
#
# {'title': '

# 2025-01-20 11:34:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/guerre-au-proche-orient/>
#
# {'title': 'Le sort incertain de Hussam Abu Safiya, « la voix du secteur de la santé dévasté de Gaza », arrêté par l’armée israélienne', 'image': 'https://img.lemde.fr/2024/12/31/0/0/2970/1980/110/73/60/0/72808d8_1735652621380-000-36rr2j7.jpg', 'description': 'L’Etat hébreu a qualifié d’«\xa0opérateur terroriste du Hamas\xa0» le pédiatre qui était le directeur du dernier hôpital encore en activité dans le nord de Gaza.'}
# 2025-01-20 11:34:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/guerre-au-proche-orient/>
#
# {'title': 'Dans la bande de Gaza, une entrave systématique à l’aide humanitaire', 'image': 'https://img.lemde.fr/2025/01/01/0/0/5274/3516/110/73/60/0/b94d8c1_1735731790252-000-36nh64r.jpg', 'description': 'En décembre, les ONG n’ont pu faire entrer que 70\xa0camions de marchandises par jour, contre 500\xa0quotidiennement avant la guerre. Cette situation, à l’origine de la famine qui sévit dans le territoire, résulte des entraves  imposées par Israël et de son inaction face aux gangs de pillards, accusent les Nations unies et des organisations.'}
# 2025-01-20 11:34:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/guerre-au-proche-orient/>
#
# {'title': 'Syrie : le retour doux-amer de l’écrivain Yassin Al-Haj Saleh à Damas', 'image': 'https://img.lemde.fr/2025/01/02/0/0/5212/3474/110/73/60/0/67c60d3_1735802448094-dsc-6215.jpg', 'description': 'Après onze ans d’exil, l’intellectuel est revenu dans son pays, en quête d’informations sur l’enlèvement, en\xa02013, de son épouse, une militante des droits de l’homme.'}
# 2025-01-20 11:34:31 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/guerre-au-proche-orient/>
#
# {'title': '« Les chances qu’un Etat de droit advienne en Syrie seront renforcées par la participation active des réfugiés syriens de France »', 'image': 'https://img.lemde.fr/2015/09/12/103/0/4094/2729/110/73/60/0/77053c1_5293456-01-06.jpg', 'description': 'La perspective de perdre le droit au séjour en France dissuade de nombreux réfugiés à contribuer à la construction d’une Syrie qui pourrait pourtant leur ressembler, alerte un collectif dans une tribune au «\xa0Monde\xa0».'}
# 2025-01-20 11:34:31 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\defer.py", line 327, in iter_errback
#     yield next(it)
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 368, in __next__
#     return next(self.data)
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\utils\python.py", line 368, in __next__
#     return next(self.data)
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     yield from iterable
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\referer.py", line 379, in <genexpr>
#     return (self._set_referer(r, response) for r in result)
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     yield from iterable
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\urllength.py", line 57, in <genexpr>
#     return (r for r in result if self._filter(r, spider))
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     yield from iterable
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\spidermiddlewares\depth.py", line 54, in <genexpr>
#     return (r for r in result if self._filter(r, response, spider))
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\core\spidermw.py", line 106, in process_sync
#     yield from iterable
#   File "C:\Users\owenb\Desktop\E4-DataEngineerProject\TDs\2Scrapy\newscrawler\newscrawler\spiders\lemonde_v3.py", line 20, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#   File "C:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\parsel\selector.py", line 135, in __getitem__
#     o = super().__getitem__(pos)
# IndexError: list index out of range
# 2025-01-20 11:34:31 [scrapy.core.engine] INFO: Closing spider (finished)
# 2025-01-20 11:34:31 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 7476,
#  'downloader/request_count': 29,
#  'downloader/request_method_count/GET': 29,
#  'downloader/response_bytes': 2632847,
#  'downloader/response_count': 29,
#  'downloader/response_status_count/200': 29,
#  'elapsed_time_seconds': 0.790142,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2025, 1, 20, 10, 34, 31, 588401, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10402043,
#  'httpcompression/response_count': 29,
#  'item_scraped_count': 1396,
#  'items_per_minute': None,
#  'log_count/DEBUG': 1426,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 10,
#  'request_depth_max': 1,
#  'response_received_count': 29,
#  'responses_per_minute': None,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 28,
#  'scheduler/dequeued/memory': 28,
#  'scheduler/enqueued': 28,
#  'scheduler/enqueued/memory': 28,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2025, 1, 20, 10, 34, 30, 798259, tzinfo=datetime.timezone.utc)}
# 2025-01-20 11:34:31 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# On peut exporter les résultats de ces retours dans différents formats de
# fichiers.
#
# -   CSV : `scrapy crawl lemondev3 -o lemonde.csv`
# -   JSON : `scrapy crawl lemondev3 -o lemonde.json`
# -   JSONLINE : `scrapy crawl lemondev3 -o lemonde.jl`
# -   XML : `scrapy crawl lemondev3 -o lemonde.xml`
#
# ### Exercice :
#
# Exécuter la spider avec les différents formats de stockage.
# Explorer ensuite le contenu des fichiers ainsi créés.

# %% [markdown]
# ## Votre premier Item
#
# La classe `Item` permet de structurer les données que l'on souhaite
# récupérer sous la forme d'un modèle. Les items doivent être définis dans
# le fichier `items.py` créé par la commande `scrapy startproject`. Les
# `Item` héritent de la class `scrapy.Item`.
#
# On veut structurer les données avec trois champs : le titre, l'image et la description. Scrapy utilise une classe `scrapy.Field` permettant de 'déclarer' ces champs. Dans notre cas :

# %%
# %load newscrawler/newscrawler/items.py

# Define here the models for your scraped items
#
# See documentation in:
# https://docs.scrapy.org/en/latest/topics/items.html

import scrapy


class ArticleItem(scrapy.Item):
    title = scrapy.Field()
    image = scrapy.Field()
    description = scrapy.Field()

# %% [markdown]
# Utiliser la classe `scrapy.Item` plutôt qu'un simple dictionnaire permet
# plus de contrôle sur la structure des données. En effet, on ne peut
# insérer dans les items que des données avec des clés 'déclarées'. Ce qui
# assure une plus grande cohérence au sein d'un projet.
#
# On peut instancier un item de plusieurs façons :

# %%
article_item = ArticleItem(title="Yann Lecun and Meta sortent Llama 3.2", image=None, description="LLama 3.2 n'est pas disponible en france")

# %%
print(article_item)
# Out:
# {'description': "LLama 3.2 n'est pas disponible en france",
#  'image': None,
#  'title': 'Yann Lecun and Meta sortent Llama 3.2'}

# %%
article_item = ArticleItem()
article_item["title"] = 'Léon Marchand recoit la légion d\'honneur'
article_item["description"] = 'Quadruple champion olympic'

# %%
print(article_item)
# Out:
# {'description': 'Quadruple champion olympic',
#  'title': "Léon Marchand recoit la légion d'honneur"}

# %% [markdown]
# La définition d'un item permet de palier toutes les erreurs de typo dans
# les champs.

# %%
article_item = ArticleItem()
article_item["titelkjwnxvmnscbvmknxc"] = 'Erreur exemple'
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 2
#       1 article_item = ArticleItem()
# ----> 2 article_item["titelkjwnxvmnscbvmknxc"] = 'Erreur exemple'
#
# File c:\Users\owenb\AppData\Local\Programs\Python\Python310\lib\site-packages\scrapy\item.py:98, in Item.__setitem__(self, key, value)
#      96     self._values[key] = value
#      97 else:
# ---> 98     raise KeyError(f"{self.__class__.__name__} does not support field: {key}")
#
# KeyError: 'ArticleItem does not support field: titelkjwnxvmnscbvmknxc'

# %% [markdown]
# Les items héritent des dictionnaires Python, et possèdent donc toutes
# les méthodes de ceux-ci :

# %%
article_item = ArticleItem(title="Nouvelle lamborghini")
print(article_item["title"])  # Méthode __getitem__()
print(article_item.get("description", "no description provided"))  # Méthode get()
# Out:
# Nouvelle lamborghini
# no description provided

# %% [markdown]
# On peut transformer un `Item` en dictionnaire très facilement, en le
# passant au constructeur:

# %%
article_item = ArticleItem(title="Drone DJI")
print(type(article_item))
dict_item = dict(article_item)
print(type(dict_item))
print(dict_item)
# Out:
# <class '__main__.ArticleItem'>
# <class 'dict'>
# {'title': 'Drone DJI'}

# %% [markdown]
# On intègre maintenant cet item dans notre spider.

# %%
# %load newscrawler/newscrawler/spiders/lemonde_v4.py

class LemondeSpider(scrapy.Spider):
    name = "lemondev4"
    allowed_domains = ["www.lemonde.fr"]
    start_urls = ['https://www.lemonde.fr']

    def parse(self, response, **kwargs):
        all_links = {
            name: response.urljoin(url) for name, url in zip(
                response.css("#nav-markup .Nav__item")[3].css("a::text").extract(),
                response.css("#nav-markup .Nav__item")[3].css("a::attr(href)").extract())
        }
        for link in all_links.values():
            yield Request(link, callback=self.parse_category)

    def parse_category(self, response):
        for article in response.css(".river")[0].css(".teaser"):
            title = self.clean_spaces(article.css("h3::text").extract_first())
            image = article.css("img::attr(data-src)").extract_first()
            description = article.css("p::text").extract_first()
            yield ArticleItem(
                title=title,
                image=image,
                description=description
            )

    def clean_spaces(self, string):
        if string:
            return " ".join(string.split())

# %% [markdown]
# On voit bien que le générateur retourne maintenant un `Item`.

# %% [markdown]
# ### Exercice :
#
# Relancer la spider pour vérifier le bon déroulement de l'extraction.

# %%
# !cd newscrawler && scrapy crawl lemondev4
# Out:
# 2024-10-08 12:12:43 [scrapy.utils.log] INFO: Scrapy 2.11.2 started (bot: newscrawler)
# 2024-10-08 12:12:43 [scrapy.utils.log] INFO: Versions: lxml 5.3.0.0, libxml2 2.12.9, cssselect 1.2.0, parsel 1.9.1, w3lib 2.2.1, Twisted 24.7.0, Python 3.12.6 (main, Sep  6 2024, 19:03:47) [Clang 16.0.0 (clang-1600.0.26.3)], pyOpenSSL 24.2.1 (OpenSSL 3.3.2 3 Sep 2024), cryptography 43.0.1, Platform macOS-15.0-arm64-arm-64bit
# 2024-10-08 12:12:43 [scrapy.addons] INFO: Enabled addons:
# []
# 2024-10-08 12:12:43 [py.warnings] WARNING: /Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/utils/request.py:254: ScrapyDeprecationWarning: '2.6' is a deprecated value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting.
#
# It is also the default value. In other words, it is normal to get this warning if you have not defined a value for the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting. This is so for backward compatibility reasons, but it will change in a future version of Scrapy.
#
# See the documentation of the 'REQUEST_FINGERPRINTER_IMPLEMENTATION' setting for information on how to handle this deprecation.
#   return cls(crawler)
#
# 2024-10-08 12:12:43 [scrapy.utils.log] DEBUG: Using reactor: twisted.internet.selectreactor.SelectReactor
# 2024-10-08 12:12:43 [scrapy.extensions.telnet] INFO: Telnet Password: 839da49eeffb3fb3
# 2024-10-08 12:12:43 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.logstats.LogStats']
# 2024-10-08 12:12:43 [scrapy.crawler] INFO: Overridden settings:
# {'BOT_NAME': 'newscrawler',
#  'NEWSPIDER_MODULE': 'newscrawler.spiders',
#  'ROBOTSTXT_OBEY': True,
#  'SPIDER_MODULES': ['newscrawler.spiders']}
# 2024-10-08 12:12:43 [scrapy.middleware] INFO: Enabled downloader middlewares:
# ['scrapy.downloadermiddlewares.offsite.OffsiteMiddleware',
#  'scrapy.downloadermiddlewares.robotstxt.RobotsTxtMiddleware',
#  'scrapy.downloadermiddlewares.httpauth.HttpAuthMiddleware',
#  'scrapy.downloadermiddlewares.downloadtimeout.DownloadTimeoutMiddleware',
#  'scrapy.downloadermiddlewares.defaultheaders.DefaultHeadersMiddleware',
#  'scrapy.downloadermiddlewares.useragent.UserAgentMiddleware',
#  'scrapy.downloadermiddlewares.retry.RetryMiddleware',
#  'scrapy.downloadermiddlewares.redirect.MetaRefreshMiddleware',
#  'scrapy.downloadermiddlewares.httpcompression.HttpCompressionMiddleware',
#  'scrapy.downloadermiddlewares.redirect.RedirectMiddleware',
#  'scrapy.downloadermiddlewares.cookies.CookiesMiddleware',
#  'scrapy.downloadermiddlewares.httpproxy.HttpProxyMiddleware',
#  'scrapy.downloadermiddlewares.stats.DownloaderStats']
# 2024-10-08 12:12:43 [scrapy.middleware] INFO: Enabled spider middlewares:
# ['scrapy.spidermiddlewares.httperror.HttpErrorMiddleware',
#  'scrapy.spidermiddlewares.referer.RefererMiddleware',
#  'scrapy.spidermiddlewares.urllength.UrlLengthMiddleware',
#  'scrapy.spidermiddlewares.depth.DepthMiddleware']
# 2024-10-08 12:12:43 [scrapy.middleware] INFO: Enabled item pipelines:
# []
# 2024-10-08 12:12:43 [scrapy.core.engine] INFO: Spider opened
# 2024-10-08 12:12:44 [scrapy.extensions.logstats] INFO: Crawled 0 pages (at 0 pages/min), scraped 0 items (at 0 items/min)
# 2024-10-08 12:12:44 [scrapy.extensions.telnet] INFO: Telnet console listening on 127.0.0.1:6023
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/robots.txt> (referer: None)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: None)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/campus/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/education/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/podcasts/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sport/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/le-fil-good/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/intimites/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sante/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/pixels/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/disparitions/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/sciences/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/les-decodeurs/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/afrique/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/actualite-en-continu/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/guadeloupe/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/societe/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/international/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/climat/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/politique/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/donald-trump/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/7-octobre-2023-un-an-apres/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/proces-des-viols-de-mazan/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/guerre-au-proche-orient/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/crise-ukrainienne/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/gouvernement-barnier/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.engine] DEBUG: Crawled (200) <GET https://www.lemonde.fr/election-presidentielle-americaine-2024/> (referer: https://www.lemonde.fr)
# 2024-10-08 12:12:44 [scrapy.core.scraper] ERROR: Spider error processing <GET https://www.lemonde.fr/le-monde-et-vous/> (referer: https://www.lemonde.fr)
# Traceback (most recent call last):
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/utils/defer.py", line 279, in iter_errback
#     yield next(it)
#           ^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/utils/python.py", line 350, in __next__
#     return next(self.data)
#            ^^^^^^^^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#              ^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/spidermiddlewares/referer.py", line 352, in <genexpr>
#     return (self._set_referer(r, response) for r in result or ())
#                                                     ^^^^^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#              ^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/spidermiddlewares/urllength.py", line 27, in <genexpr>
#     return (r for r in result or () if self._filter(r, spider))
#                        ^^^^^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#              ^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/spidermiddlewares/depth.py", line 31, in <genexpr>
#     return (r for r in result or () if self._filter(r, response, spider))
#                        ^^^^^^^^^^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/scrapy/core/spidermw.py", line 106, in process_sync
#     for r in iterable:
#              ^^^^^^^^
#   File "/Users/jeremy/esiee/DataEngineerTools/2Scrapy/newscrawler/newscrawler/spiders/lemonde_v4.py", line 21, in parse_category
#     for article in response.css(".river")[0].css(".teaser"):
#                    ~~~~~~~~~~~~~~~~~~~~~~^^^
#   File "/Users/jeremy/.local/share/virtualenvs/DataEngineerTools-2yTkhyK3/lib/python3.12/site-packages/parsel/selector.py", line 135, in __getitem__
#     o = super().__getitem__(pos)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
# IndexError: list index out of range
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Alors que l’isolement est souvent associé aux personnes '
#                 'âgées, les plus jeunes sont nombreux à en souffrir\xa0: un '
#                 'mal-être grandissant, qui peut avoir de sérieuses '
#                 'conséquences sur la santé mentale et physique.',
#  'image': 'https://img.lemde.fr/2024/10/03/0/0/3000/2000/110/73/60/0/31e092e_1727956585190-solitude-des-ei-tudiants2.jpg',
#  'title': 'Une « épidémie de solitude » se répand chez les jeunes'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'On n’est pas sérieux quand on a 17\xa0ans… Pas si sûr. «\xa0'
#                 'Le Monde\xa0» donne la parole à de jeunes gens qui évoquent '
#                 'leurs états d’âme, leurs envies, leurs difficultés. Lazare '
#                 '(le prénom a été modifié), 13\xa0ans, habite un petit village '
#                 'd’Ille-et-Vilaine. Il est entré en 4ᵉ, mais il a toujours '
#                 'l’impression d’être en CM2.',
#  'image': 'https://img.lemde.fr/2024/10/02/0/0/1500/1000/110/73/60/0/8ff642b_1727882079475-illustration-finale-lazare-zoevadim.jpg',
#  'title': 'Ma vie d’ado : « Souvent je traîne seul aux récrés, parce qu’il y a '
#           'un groupe de gars qui me traite de gros, de pédé »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Ex-directeur de cabinet au Quai d’Orsay, ce fils d’un réfugié '
#                 'uruguayen a pris ses fonctions mardi 1ᵉʳ\xa0octobre à la tête '
#                 'd’une école qu’il refuse de voir comme «\xa0un objet '
#                 'politique\xa0».',
#  'image': 'https://img.lemde.fr/2024/10/04/1/0/7488/4992/110/73/60/0/e8cdbdc_1728054504127-000-36gf7pl.jpg',
#  'title': 'A la tête de Sciences Po, Luis Vassy, un diplomate de « sang-froid '
#           '» pour « faire baisser la pression »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'A 28\xa0ans, il réunit plus de 370\xa0000 abonnés sur son '
#                 'compte Instagram, The Impact Story. Il s’exprimera sur la '
#                 'question de la mobilisation de la jeunesse lors du forum '
#                 'Science 4\xa0Action organisé par l’Institut de recherche pour '
#                 'le développement, le 7\xa0octobre.',
#  'image': 'https://img.lemde.fr/2024/09/20/61/0/800/533/110/73/60/0/6573207_1726836493271-mamad.jpg',
#  'title': 'Avec Mamadou Dembele, une écologie positive et consciente'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Charlotte Espel a rencontré des victimes de harcèlement ou de '
#                 'viol qui luttent pour que ces violences ne soient plus '
#                 'passées sous silence.',
#  'image': 'https://img.lemde.fr/2024/09/27/0/124/1303/869/110/73/60/0/9356c43_1727432008416-c389tudiantesenterrainminc3a92frc3a9alisc3a9parcharlotteespel-4.jpeg',
#  'title': '« Etudiantes en terrain miné », sur LCP : des jeunes femmes '
#           'agressées sexuellement durant leurs études prennent la parole'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Une étude de l’association Elles bougent, publiée lundi 23\xa0'
#                 'septembre, rappelle à quel point les stéréotypes de genre '
#                 'entravent l’accès des femmes à ces secteurs.',
#  'image': 'https://img.lemde.fr/2024/09/27/1/0/7989/5326/110/73/60/0/41de249_1727433471368-000-32ed8tw.jpg',
#  'title': 'De l’école à l’entreprise, les femmes toujours découragées de faire '
#           'carrière dans les métiers scientifiques et techniques'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Tom Chevalier, chercheur au CNRS, en appelle, dans une '
#                 'tribune au «\xa0Monde\xa0», à s’inspirer du système de '
#                 'bourses des pays du nord de l’Europe, où le «\xa0statut '
#                 'd’adulte\xa0» des étudiants est, selon lui, reconnu.',
#  'image': 'https://img.lemde.fr/2024/09/25/0/0/8256/5504/110/73/60/0/cc5efa3_5777055-01-06.jpg',
#  'title': '« Les niveaux de précarité étudiante sont bien plus bas dans les '
#           'pays où les aides ne dépendent plus des ressources parentales »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'La communauté universitaire est dans l’expectative quant aux '
#                 'marges de manœuvre financières dont elle pourra disposer '
#                 'en\xa02025\xa0et aux intentions de Patrick Hetzel, le nouveau '
#                 'ministre au profil libéral-conservateur.',
#  'image': 'https://img.lemde.fr/2024/09/30/3/0/5900/3933/110/73/60/0/7bec707_1727710103538-jmug240923170.jpg',
#  'title': 'Des coupes budgétaires redoutées dans les universités et la '
#           'recherche'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Le versement d’une allocation sans condition de revenu dès '
#                 'l’inscription dans l’enseignement supérieur ou professionnel '
#                 'permettrait de favoriser l’autonomie des étudiants, estiment '
#                 'les présidents d’université Nathalie Drach-Temam et Florent '
#                 'Pigeon dans une tribune au «\xa0Monde\xa0».',
#  'image': 'https://img.lemde.fr/2024/04/25/0/0/6720/4480/110/73/60/0/b22c6a2_5295133-01-06.jpg',
#  'title': '« Nous appelons de nos vœux un grand programme d’investissements '
#           'd’avenir en faveur de notre jeunesse étudiante »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Les inégalités salariales entre les hommes et les femmes '
#                 'n’épargnent pas les plus diplômées, confrontées aux mêmes '
#                 'types de pratiques et de stéréotypes que le reste de la '
#                 'société. Selon la Conférence des grandes écoles, l’écart est '
#                 'de 5,2\xa0% à la sortie des études.',
#  'image': 'https://img.lemde.fr/2024/09/26/52/0/2138/1425/110/73/60/0/80da44a_1727354035060-inei-galitei-hd.jpg',
#  'title': 'La bataille des jeunes diplômées pour l’égalité des salaires : « Il '
#           'faut faire comme les garçons, demander plus que ce que l’on pense '
#           'mériter »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Les grandes entreprises de la tech s’offrent les meilleurs '
#                 'spécialistes de l’intelligence artificielle, créant un '
#                 'véritable appel d’air et privant d’experts les écoles '
#                 'd’ingénieurs et les organismes de recherche, qui cherchent '
#                 'des parades pour les séduire.',
#  'image': 'https://img.lemde.fr/2024/09/27/0/0/2125/1417/110/73/60/0/c2962aa_1727426581463-le-monde-campus-ei-coles-et-ai-1-exe.jpg',
#  'title': '« Un jeune chercheur en IA peut se voir offrir par les Gafam '
#           'jusqu’à 130 000 euros par an » : dans les écoles d’ingénieurs, les '
#           'profs, attirés par le privé, manquent à l’appel'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': '«\xa0Premières fois\xa0»\xa0: récits de moments charnières '
#                 'autour du passage à l’âge adulte. Cette semaine, Lilian, '
#                 'jeune breton de 20\xa0ans, raconte ses premiers pas à '
#                 'Marseille en tant que nouvel étudiant en école '
#                 'd’architecture.',
#  'image': 'https://img.lemde.fr/2022/03/09/0/0/3543/2362/110/73/60/0/78365e0_293879512-illu-lemonde-campus-web.jpg',
#  'title': '« J’avais tenté plusieurs écoles mais j’ai fini par choisir celle '
#           'de Marseille parce que je savais que les loyers seraient moins '
#           'chers qu’à Paris »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': '«\xa0J’avais 20\xa0ans\xa0»\xa0: «\xa0Le Monde\xa0» interroge '
#                 'une personnalité sur ses années d’études et son passage à '
#                 'l’âge adulte. Ce mois-ci, la chanteuse, compositrice et '
#                 'poétesse raconte comment la musique l’habite depuis toute '
#                 'petite et la déflagration qu’a été pour elle la découverte du '
#                 'chant.',
#  'image': 'https://img.lemde.fr/2024/04/08/80/0/3780/2520/110/73/60/0/f721ba8_1712563069375-jean-franci-ois-robert1.jpeg',
#  'title': 'Clara Ysé : « Comme j’étais méga-timide, la musique et l’écriture '
#           'étaient des espaces dans lesquels j’avais l’impression de respirer '
#           'plus grand »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Conditions de travail indignes, pénurie de personnel, manque '
#                 'd’encadrement des étudiants, les jeunes se détournent '
#                 'précocement des métiers du social, le secteur peine à stopper '
#                 'l’hémorragie.',
#  'image': 'https://img.lemde.fr/2024/09/24/0/0/2125/1417/110/73/60/0/73a65b6_1727178770892-le-monde-final.jpg',
#  'title': '« La violence était totalement banalisée, quotidienne, je n’étais '
#           'pas encadré » : la crise du secteur médico-social frappe les jeunes '
#           'travailleurs sociaux'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Logement, ressources, jobs à côté des études\xa0; les effets '
#                 'de la crise sanitaire sur les étudiants se sont globalement '
#                 'estompés, selon une nouvelle note de l’observatoire de la vie '
#                 'étudiante. Mais leur santé mentale et leur précarité restent '
#                 'préoccupantes.',
#  'image': 'https://img.lemde.fr/2024/09/21/0/2/4476/2984/110/73/60/0/70b06a9_1726898882668-000-9644ra.jpg',
#  'title': 'Pour les étudiants, le retour d’une précarité « structurelle » '
#           'après le Covid-19'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Entre contraintes économiques, injonction à l’autonomie et '
#                 'confort du nid familial, quelque cinq millions de jeunes '
#                 'adultes, des «\xa0Tanguy\xa0», vivent encore chez leurs '
#                 'parents.',
#  'image': 'https://img.lemde.fr/2024/09/19/53/0/2138/1425/110/73/60/0/9f98016_1726735890689-le-monde-tanguy-2-copie.jpg',
#  'title': '« Rester chez mes parents, c’est le filet de sécurité, ça me permet '
#           'de rembourser mon prêt, de mettre de l’argent de côté »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Former les profs pour faire évoluer les enseignements afin de '
#                 'répondre aux urgences liées au dérèglement climatique\xa0: '
#                 'une évolution qui se heurte encore largement aux contraintes '
#                 'financières et organisationnelles des établissements.',
#  'image': 'https://img.lemde.fr/2024/09/21/0/0/2125/1417/110/73/60/0/cc0a1a9_1726924813671-coutroutsios-climat-profs-2.jpg',
#  'title': 'Dans l’enseignement supérieur, des obstacles pour former les '
#           'enseignants à la transition écologique'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Peu intégrées dans les communautés queer, tout en étant '
#                 'exclues de la norme hétéro, les personnes bis revendiquent '
#                 'plus de visibilité. De jeunes collectifs s’organisent pour '
#                 'créer des espaces de solidarité. Dimanche 22\xa0septembre '
#                 's’élancera une marche, la veille de la Journée internationale '
#                 'de la visibilité de la bisexualité.',
#  'image': 'https://img.lemde.fr/2024/09/20/0/0/2125/1417/110/73/60/0/0d41dc6_1726834812893-colo-lemonde-biphobie-v03.jpg',
#  'title': 'En marge chez les LGBT comme chez les hétéros, les bisexuels '
#           'veulent sortir du placard : « Tout nous dit qu’on n’existe pas »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Agé de 44\xa0ans, l’ancien directeur de cabinet de Stéphane '
#                 'Séjourné au Quai d’Orsay, issu de la même promotion '
#                 'qu’Emmanuel Macron à l’ENA, met en avant sa volonté '
#                 'd’apaisement et son désir de «\xa0redresser l’image\xa0» de '
#                 'l’institution.',
#  'image': 'https://img.lemde.fr/2024/09/20/0/0/6240/4160/110/73/60/0/76be849_1726847035559-080-hl-mbertrand-913396.jpg',
#  'title': 'Sciences Po : le diplomate Luis Vassy nommé directeur après de '
#           'longs mois de crise'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Le Franco-Uruguayen de 44\xa0ans dirigeait depuis\xa02022 le '
#                 'cabinet des ministres des affaires étrangères successifs, '
#                 'Catherine Colonna puis Stéphane Séjourné, après avoir été '
#                 'notamment ambassadeur de France aux Pays-Bas.',
#  'image': 'https://img.lemde.fr/2024/09/16/1/0/7488/4992/110/73/60/0/3823a03_5696664-01-06.jpg',
#  'title': 'Sciences Po : le diplomate Luis Vassy désigné directeur, après des '
#           'mois de crise de gouvernance'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'La montée en puissance de cette matière correspond à une '
#                 'demande de plus en plus pressante de compétences. Mais sa '
#                 'pratique, qui nécessite de solides connaissances en droit '
#                 'administratif, peut être une source de désillusion chez '
#                 'certains jeunes.',
#  'image': 'https://img.lemde.fr/2024/09/19/0/6/5488/3659/110/73/60/0/e070d3d_1726735230075-000-9rf6b4.jpg',
#  'title': 'Les élèves juristes du droit de l’environnement « veulent bosser '
#           'avec Greta Thunberg »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'L’été est fini, c’est le moment du grand plongeon dans les '
#                 'études supérieures. Si la curiosité est grande, il faut '
#                 'apprendre l’autonomie et s’adapter à un univers bien '
#                 'différent.',
#  'image': 'https://img.lemde.fr/2024/01/15/0/0/5155/3437/110/73/60/0/dc9c0c8_1705328420468-sophie-rodriguez-basile-marquer-le-monde-12.jpg',
#  'title': '« Ça fait bizarre tous ces changements » : après Parcoursup, une '
#           'nouvelle vie commence pour les étudiants'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Dans les grandes entreprises, les réseaux de jeunes de moins '
#                 'de 35\xa0ans ont le vent en poupe. Les jeunes générations '
#                 's’en servent pour faire émerger leur voix et consolider leur '
#                 'réseau.',
#  'image': 'https://img.lemde.fr/2014/10/20/0/774/1241/827/110/73/60/0/54e26e2_NYK503_MARKETS-STOCKS-_1020_11.JPG',
#  'title': 'Les réseaux de jeunes ou comment les entreprises misent sur '
#           'l’entre-soi de leurs nouvelles recrues pour les fidéliser'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Alcool en quantité, humiliations, agressions sexuelles\xa0: '
#                 'sous le couvert de la tradition et de l’intégration, des '
#                 'pratiques interdites continuent, au nom de l’«\xa0esprit '
#                 'carabin\xa0».',
#  'image': 'https://img.lemde.fr/2024/09/17/12/0/3916/2610/110/73/60/0/30f960d_1726560772442-000-par2149698.jpg',
#  'title': 'Dans les facultés de médecine, le bizutage persiste, « continuum où '
#           'la victime devient le bourreau »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Les jeunes de la génération Z seraient-ils devenus «\xa0'
#                 'in-manageables\xa0»\xa0? Alors que de nombreuses recherches '
#                 'déconstruisent les stéréotypes sur le rapport au travail des '
#                 'nouvelles générations, le monde de l’entreprise semble buter '
#                 'sur le management des plus jeunes.',
#  'image': 'https://img.lemde.fr/2024/08/28/0/0/3000/2000/110/73/60/0/fdd30da_1724858313147-gei-nei-ration-z.jpg',
#  'title': '« Le travail ne serait pour les jeunes plus qu’une pièce du puzzle '
#           'de leur vie » : le grand malentendu des générations au travail'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Le ministère de l’éducation a acté, lundi 16\xa0septembre, '
#                 'l’abandon du projet de rendre l’examen obligatoire pour '
#                 'passer en seconde et d’en modifier les conditions d’obtention '
#                 'dès la session prochaine. Le choix de poursuivre ou '
#                 'd’enterrer cette réforme reviendra au prochain gouvernement.',
#  'image': 'https://img.lemde.fr/2024/09/16/0/0/7581/5054/110/73/60/0/382c9c8_1726496457146-000-36fr6a7.jpg',
#  'title': 'La réforme du brevet, mesure phare du « choc des savoirs » de '
#           'Gabriel Attal, est abandonnée pour 2025'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Les changements – accroître le poids des épreuves terminales '
#                 'et conditionner l’accès au lycée à l’obtention du brevet – '
#                 'avaient été annoncés par Gabriel Attal en décembre\xa02023. '
#                 'Mais les textes n’ont pas été publiés à temps, selon le '
#                 'ministère de l’éducation nationale.',
#  'image': 'https://img.lemde.fr/2024/09/16/0/0/7479/4986/110/73/60/0/74dd752_1726505864542-000-36fn7zp.jpg',
#  'title': 'Brevet des collèges : la nouvelle formule n’entrera pas en vigueur '
#           'pour l’année scolaire en cours'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Depuis plusieurs années, le chef-lieu de la Haute-Vienne '
#                 'attire nombre d’étudiants dans un contexte d’inflation et de '
#                 'hausse des frais d’inscription.',
#  'image': 'https://img.lemde.fr/2024/09/09/0/1/3541/2361/110/73/60/0/be2d4a8_1725893348210-limoges-ville-etudiante-a-thierry-laporte-pour-le-monde-11.jpg',
#  'title': 'Limoges, classée ville étudiante la moins chère de France : « '
#           'J’imaginais un endroit paumé dans la diagonale du vide, c’est tout '
#           'le contraire »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': '«\xa0Premières fois\xa0»\xa0: récits de moments charnières '
#                 'autour du passage à l’âge adulte. Cette semaine, Kim '
#                 'Martinez, 23\xa0ans, explique sa relation avec sa jumelle, '
#                 'entre rivalité sportive et indépendance.',
#  'image': 'https://img.lemde.fr/2022/03/09/0/0/3543/2362/110/73/60/0/78365e0_293879512-illu-lemonde-campus-web.jpg',
#  'title': '« Avec ma sœur jumelle, partout on nous désigne comme “Kim et '
#           'Anna”. Nous sommes indissociables »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Pilier des études de santé, ce dispositif quasi gratuit '
#                 'proposé par des étudiants à leurs cadets de première année se '
#                 'révèle indispensable à leur réussite. Des prépas privées ont '
#                 'aussi investi ce créneau, facturant leurs services autour de '
#                 '6\xa0000\xa0euros l’année.',
#  'image': 'https://img.lemde.fr/2024/09/13/0/0/4999/3333/110/73/60/0/a67573e_1726235009598-bg-5sept24-france-facmedecine-18013.JPG',
#  'title': '« Mangez bien », « faites des pauses », « ne vous comparez pas » : '
#           'à l’université Paris Cité, le tutorat, PME de la réussite pour les '
#           'étudiants en médecine'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Depuis le décès de Richard Descoings, en\xa02012, l’école '
#                 'traverse une crise de gouvernance. Les deux derniers '
#                 'dirigeants ont été emportés par des scandales et '
#                 'l’établissement est accusé d’être le terreau d’une prétendue '
#                 'culture «\xa0woke\xa0» après les mobilisations en faveur de '
#                 'la Palestine. Des troubles qui ont dissuadé plusieurs '
#                 'candidats au poste de directeur, dont la désignation doit '
#                 'être officialisée le 20\xa0septembre.',
#  'image': 'https://img.lemde.fr/2024/09/10/136/0/1500/1000/110/73/60/0/e2d5f5c_349029-3388424.jpg',
#  'title': 'Sciences Po cherche désespérément la bonne direction'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'La conférence des doyens de médecine, jeudi 12\xa0septembre, '
#                 'a remis en cause la réforme de 2020, qui a créé deux '
#                 'nouvelles voies d’accès aux études de santé.',
#  'image': 'https://img.lemde.fr/2024/09/13/0/0/4999/3333/110/73/60/0/417867b_1726217846555-bg-5sept24-france-facmedecine-18001.JPG',
#  'title': '« Illisible » et « trop complexe » : la réforme de l’entrée dans '
#           'les études de santé critiquée par les doyens'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'De nombreuses formations ont été créées ces dernières années '
#                 'pour former des aspirants DJ. Désormais, ces artistes doivent '
#                 'maîtriser l’image, la lumière et la gestion des réseaux '
#                 'sociaux.',
#  'image': 'https://img.lemde.fr/2024/09/12/0/0/2125/1417/110/73/60/0/8fa3811_1726132604572-final-dj1.jpg',
#  'title': '« Aujourd’hui, il y a des DJ à tous les coins de rue » : comment '
#           'les jeunes se forment pour se distinguer sur un marché '
#           'concurrentiel'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Plusieurs communes, de gauche mais aussi du centre et de '
#                 'droite, ont mis en place ce «\xa0coup de pouce\xa0» pour les '
#                 'étudiants inscrits en études supérieures. Une manière de '
#                 'compléter un système de bourses insuffisant.',
#  'image': 'https://img.lemde.fr/2024/09/06/0/0/4308/2872/110/73/60/0/acd30bc_1725629148172-000-32lm9lt.jpg',
#  'title': 'Ces villes qui expérimentent un revenu minimum pour les étudiants'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Le Sigem, le «\xa0Financial Times\xa0», «\xa0L’Etudiant\xa0»… '
#                 'Chaque année, plusieurs organismes publient un classement des '
#                 'écoles de commerce. Sont-ils ou ont-ils été un critère de '
#                 'choix important, voire majeur\xa0dans votre orientation\xa0? '
#                 'Livrez-nous votre témoignage.',
#  'image': 'https://img.lemde.fr/2017/11/03/0/1/1797/1198/110/73/60/0/608fb19_1547-ebj3u3.jf2tv2huxr.jpg',
#  'title': 'Les classements des grandes écoles de commerce influent-ils sur '
#           'votre choix d’un établissement ?'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'En 6ᵉ et 5ᵉ, les cours de mathématiques et de français sont '
#                 'organisés par groupes, une mesure du «\xa0choc des savoirs\xa0'
#                 '» de l’ancien ministre de l’éducation Gabriel Attal. Des '
#                 'groupes de niveau, rebaptisés «\xa0groupes de besoins\xa0» '
#                 'par Nicole Belloubet, qui recommande d’appliquer la mesure '
#                 'avec souplesse, n’existant, en pratique, pas partout.',
#  'image': 'https://img.lemde.fr/2024/09/10/23/125/1689/1126/110/73/60/0/0dd3861_1726009154441-image0.jpeg',
#  'title': 'Dans les collèges, des « groupes de besoins » à géométrie variable'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Selon le baromètre annuel réalisé par le Crédoc et l’Injep, '
#                 'sept jeunes sur dix estiment que leur vie actuelle correspond '
#                 'à leurs attentes. Il met en avant des écarts importants selon '
#                 'le genre ou la situation sociale.',
#  'image': 'https://img.lemde.fr/2024/09/10/0/0/5391/3594/110/73/60/0/510e022_1725975205410-000-34x76de.jpg',
#  'title': 'Les jeunes femmes sont moins confiantes face à l’avenir'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'L’inflation et la hausse des frais de rentrée vont peser sur '
#                 'une population étudiante déjà confrontée à une précarité '
#                 'structurelle. Pour s’en sortir, les jeunes jonglent entre '
#                 'petits boulots, soutien familial et aide des associations.',
#  'image': 'https://img.lemde.fr/2024/09/06/0/20/2710/1807/110/73/60/0/8060fcb_1725624683710-galei-re-etudiant-hd.jpg',
#  'title': '« Avec un peu plus d’argent, je pourrais faire autre chose que '
#           'travailler, manger et dormir » : pour les étudiants précaires, une '
#           'nouvelle rentrée sous le signe des privations'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Alors que le marché de l’emploi leur est plutôt favorable, '
#                 'les étudiants redoutent leur insertion dans le monde du '
#                 'travail, indique une nouvelle étude de l’Association pour '
#                 'l’emploi des cadres (APEC).',
#  'image': 'https://img.lemde.fr/2024/09/06/26/0/5449/3632/110/73/60/0/e77a270_1725625888597-000-9n647m.jpg',
#  'title': 'Le monde « impitoyable » du travail vu par les étudiants'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': '«\xa0Premières fois\xa0»\xa0: récits de moments charnières '
#                 'autour du passage à l’âge adulte. Cette semaine, Bartolomé, '
#                 'attaché de presse de 26\xa0ans, raconte comment il s’est '
#                 'décidé à sauter le pas de la contraception masculine.',
#  'image': 'https://img.lemde.fr/2022/06/03/0/0/3543/2362/110/73/60/0/fd6d539_1654262936192-le-monde-campus-v03.jpg',
#  'title': '« L’idée de recourir à la contraception masculine m’est venue '
#           'progressivement, car il est injuste que toute la charge mentale et '
#           'les risques reposent sur les femmes »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Fan des années 1980, 1990\xa0et 2000, une partie de la '
#                 'jeunesse se réfugie dans un passé fantasmé,\xa0persuadée que '
#                 '«\xa0c’était mieux avant\xa0». De la Game Boy à Kate Bush, '
#                 'les références d’antan font office d’antidote aux impasses '
#                 'd’aujourd’hui.',
#  'image': 'https://img.lemde.fr/2024/09/04/416/0/1957/1304/110/73/60/0/3ea593f_1725437055957-02-240903-lemonde-epoque-doudous-gbelveze-vdef-hd-jpg-srvb-300dpi.jpg',
#  'title': 'Pour atténuer les angoisses du présent, les jeunes se tournent vers '
#           'des « époques doudous »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Les élèves du collège Dora-Maar de Saint-Denis n’ont pas pu '
#                 'faire leur rentrée dans leur établissement, situé en plein '
#                 'cœur du village olympique. En revanche, chacun d’entre eux '
#                 'pourra aller voir deux épreuves paralympiques, mille places '
#                 'ayant été offertes à ce collège par l’éducation nationale.',
#  'image': 'https://img.lemde.fr/2024/09/05/0/201/5128/3419/110/73/60/0/e8bb0db_1725548122305-870531.jpg',
#  'title': '« C’est comme s’ils n’avaient pas de handicap » : des collégiens de '
#           'Saint-Denis aux épreuves de para athlétisme'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Une frontière invisible se dessine au seuil de cette pièce, '
#                 'considérée comme un refuge inviolable par les collégiens et '
#                 'lycéens, constate Clara Georges pour la newsletter «\xa0'
#                 'Darons Daronnes\xa0».',
#  'image': 'https://img.lemde.fr/2024/09/06/0/1/1497/998/110/73/60/0/a0dc252_1725609709535-web-img-9601.jpg',
#  'title': 'Puis-je franchir la porte de la chambre de mon ado ?'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Le Festival des poussières, organisé fin août en Bourgogne, a '
#                 'rassemblé une jeunesse chrétienne ancrée à gauche qui se '
#                 'structure depuis plusieurs années face aux tenants d’un '
#                 'catholicisme conservateur.',
#  'image': 'https://img.lemde.fr/2024/08/28/168/0/4032/2688/110/73/60/0/28b23b9_1724835414016-img-3212.jpg',
#  'title': '« Ma foi a grandi avec mon engagement écologique » : les cathos '
#           'écolos de la génération Z veulent faire converger foi et '
#           'militantisme'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Alors que les étudiants font leur rentrée, certains d’entre '
#                 'eux se disent atteints du syndrome du «\xa0Fear of Missing '
#                 'Out\xa0», la peur de rater quelque chose. Une crainte '
#                 'difficile à gérer en pleine intégration étudiante.',
#  'image': 'https://img.lemde.fr/2024/09/04/0/0/3000/2000/110/73/60/0/82bc85d_1725444872977-colo-fomo-lemonde-v01.jpg',
#  'title': 'Le « Fomo » étudiant, cette peur de passer à côté de sa vie (et des '
#           'soirées)'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Le procès de la mort de l’étudiant, décédé\xa0après une '
#                 'soirée très arrosée, a été renvoyé à la demande des parties, '
#                 'qui veulent entendre les responsables de l’université, dont '
#                 'ils dénoncent le laxisme.',
#  'image': 'https://img.lemde.fr/2024/09/05/0/0/5208/3472/110/73/60/0/5ee5507_1725520200381-maxnewsspecial861981.jpg',
#  'title': 'Un rapport accable la faculté de médecine de Lille après la mort de '
#           'Simon Guermonprez, 19 ans, lors d’une soirée d’intégration en 2021'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'L’administrateur provisoire, Jean Bassères, a présenté un '
#                 'plan d’action pour restaurer une culture du débat et du '
#                 'dialogue qui aurait manqué. Très discrète, l’entrée en '
#                 'application d’un nouveau règlement de la vie étudiante '
#                 'pourrait créer des remous.',
#  'image': 'https://img.lemde.fr/2024/09/04/0/0/5899/3933/110/73/60/0/a45b228_1725464712452-jmug240429036.jpg',
#  'title': 'A Sciences Po, la quête d’une rentrée « sereine » malgré le renvoi '
#           'en section disciplinaire de 25 étudiants après des mois de tensions'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Benoît Huou a évoqué en introduction de son cours un courrier '
#                 'de lecteurs de la revue «\xa0The Lancet\xa0» qui évaluait, au '
#                 'début de juillet, à 186\xa0000\xa0le nombre de Palestiniens '
#                 'morts sous les coups de l’armée israélienne.',
#  'image': 'https://img.lemde.fr/2024/09/04/129/0/6856/4570/110/73/60/0/8ddaae7_1725475385964-000-par8001419.jpg',
#  'title': 'Un enseignant de la Toulouse School of Economics suspendu après '
#           'avoir appelé au boycott d’Israël'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Dans un entretien au «\xa0Monde\xa0», la sociologue de '
#                 'l’éducation Géraldine Farges explique pourquoi les '
#                 'reconversions dans l’enseignement ont augmenté ces dernières '
#                 'années.',
#  'image': 'https://img.lemde.fr/2024/09/02/0/0/6223/4149/110/73/60/0/c1c1c5c_5566779-01-06.jpg',
#  'title': '« Les enseignants reconvertis valorisent un peu moins la profession '
#           'que ceux ayant embrassé la carrière plus traditionnellement »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Les organisations s’alarment notamment de frais en hausse de '
#                 'près de 3\xa0% pour l’inscription à l’université et de 3,5\xa0'
#                 '% pour le loyer des résidences universitaires.',
#  'image': 'https://img.lemde.fr/2024/09/03/0/0/8256/5504/110/73/60/0/40ee980_1725378351308-000-346q7vd.jpg',
#  'title': 'Les syndicats étudiants lancent un « signal d’alerte » sur le coût '
#           'de la rentrée'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'L’association Le Choix de l’école, dont la raison d’être fait '
#                 'débat dans le milieu éducatif, forme des diplômés de grandes '
#                 'écoles en quête de sens, afin qu’ils deviennent enseignants '
#                 'contractuels.',
#  'image': 'https://img.lemde.fr/2024/08/31/25/0/2138/1425/110/73/60/0/4eb1e0b_1725082848321-le-monde-campus.jpg',
#  'title': 'Ces diplômés qui se tournent sur le tard vers l’éducation nationale'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'Pour améliorer les résultats et lutter contre le harcèlement, '
#                 'le gouvernement souhaite généraliser la «\xa0pause '
#                 'numérique\xa0» totale au sein des collèges. Syndicats et '
#                 'collectivités territoriales y voient une expérimentation\xa0'
#                 'inefficace et dispendieuse.',
#  'image': 'https://img.lemde.fr/2024/09/02/785/1081/428/285/110/73/60/0/448cbc5_1725315181362-image1.jpeg',
#  'title': 'L’interdiction totale du portable au collège, une mesure qui pose '
#           'beaucoup de questions'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description': 'La crise d’attractivité que connaît le métier d’enseignant ne '
#                 'permet pas de pourvoir tous les postes de professeurs dès le '
#                 'début de l’année scolaire.',
#  'image': 'https://img.lemde.fr/2024/08/31/0/0/7243/4828/110/73/60/0/02b74de_1725106137516-000-33u96d6.jpg',
#  'title': 'Un prof devant chaque classe à la rentrée : une mission devenue '
#           'impossible pour l’éducation nationale'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/campus/>
# {'description
'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'A presque un mois de l’élection présidentielle, l’enjeu de '
#                 'ces déplacements sur la côte Atlantique est également '
#                 'politique. Donald Trump a fait de la catastrophe, qui a '
#                 'provoqué la mort d’au moins 162\xa0personnes, un argument de '
#                 'campagne.',
#  'image': 'https://img.lemde.fr/2024/10/02/0/0/3702/2468/110/73/60/0/520098f_2024-10-02t181328z-42284437-rc2icaamq5xc-rtrmadp-3-storm-helene-biden.JPG',
#  'title': 'Joe Biden et Kamala Harris en visite dans les Etats touchés par '
#           'l’ouragan Helene'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Le tribunal de Nuuk, au Groenland, préfère maintenir en '
#                 'détention le militant canadien interpellé en juillet, le '
#                 'temps que la justice danoise se prononce sur la demande '
#                 'd’extradition formulée par le Japon.',
#  'image': 'https://img.lemde.fr/2024/10/02/0/0/3000/2000/110/73/60/0/ca5720d_1727885857757-349154.jpg',
#  'title': 'Le défenseur des baleines Paul Watson reste en prison, une '
#           'prolongation « disproportionnée », selon ses défenseurs'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Le groupe pétrogazier compte mettre sur le marché 3\xa0% '
#                 'd’hydrocarbures en plus, chaque année, d’ici à 2030. Cela '
#                 'tient principalement au gaz naturel liquéfié (GNL).',
#  'image': 'https://img.lemde.fr/2024/10/02/0/0/8256/5504/110/73/60/0/bcffeec_5853476-01-06.jpg',
#  'title': 'TotalEnergies prolonge encore ses prévisions de hausse de '
#           'production de pétrole et de gaz'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'L’installation permet d’expérimenter la vie sous un climat '
#                 'extrême. Une expérience, créée par l’explorateur et chercheur '
#                 'Christian Clot, qui entend ainsi pousser chacun à l’action.',
#  'image': 'https://img.lemde.fr/2024/10/02/0/0/3984/2656/110/73/60/0/6bedf82_1727886041206-imgm7927.JPG',
#  'title': 'Réchauffement climatique : une cabine à 50 °C pour « s’immerger '
#           'dans le climat du futur »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Les autorités sanitaires rappellent les dangers du Sniper '
#                 '1000, cet insecticide mortel toujours vendu illégalement en '
#                 'France malgré son interdiction depuis 2013.',
#  'image': 'https://img.lemde.fr/2023/10/09/7/0/4200/2800/110/73/60/0/aba1c21_1696865867147-000-was3686434.jpg',
#  'title': 'Punaises de lit : les douanes alertent sur la multiplication des '
#           'saisies d’un insecticide interdit en France'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Une start-up s’est lancée dans la production de larves de '
#                 'mouches utilisées comme source de protéines dans les élevages '
#                 'aviaires et porcins, ainsi que dans les exploitations '
#                 'piscicoles.',
#  'image': 'https://img.lemde.fr/2024/10/02/0/0/5719/3813/110/73/60/0/c1d148a_1727860604061-dsc-0322.JPG',
#  'title': 'Côte d’Ivoire : les asticots, un substitut qui fait mouche face aux '
#           'farines animales'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Le typhon, qui a déjà fait plusieurs blessés sur l’île et qui '
#                 'est caractérisé par des vents soutenus de 173\xa0'
#                 'kilomètres-heure et des rafales pouvant atteindre 209\xa0'
#                 'kilomètres-heure, devrait toucher terre jeudi vers 10\xa0'
#                 'heures, plutôt que mercredi, d’après les météorologues.',
#  'image': 'https://img.lemde.fr/2024/10/02/62/0/6000/4000/110/73/60/0/ac903ac_54cec975dd3d4feda2749a97759288cc-0-a292c06f4974492e94a1a5cc6d87519b.jpg',
#  'title': 'A l’approche du typhon Krathon, Taïwan se barricade'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'I4CE, le think tank présidé par Jean Pisani-Ferry, propose de '
#                 'durcir certaines réglementations et de prioriser les dépenses '
#                 'vers les aides et infrastructures qui bénéficient le plus aux '
#                 'classes moyennes et populaires.',
#  'image': 'https://img.lemde.fr/2024/10/01/0/0/2047/1365/110/73/60/0/07343c3_1727792763240-unnamed.jpg',
#  'title': 'Transition écologique : les préconisations des experts de '
#           'l’Institut de l’économie pour le climat pour atténuer l’impact des '
#           'coupes budgétaires'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Après des décennies de spoliations, les tribus autochtones du '
#                 'bassin du Klamath ont obtenu que les quatre barrages '
#                 'installés le long de la rivière soient démantelés. Dans ce '
#                 'podcast, Corine Lesnes, correspondante du «\xa0Monde\xa0» à '
#                 'San Francisco, raconte cette victoire qui s’inscrit dans le '
#                 'mouvement dit du «\xa0renouveau indien\xa0».',
#  'image': 'https://img.lemde.fr/2024/10/01/0/0/1800/1200/110/73/60/0/f472f2f_1727792447751-klamath.jpg',
#  'title': 'En Californie, comment des tribus indigènes ont retrouvé leur '
#           'fleuve sacré'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Joe Biden et Kamala Harris se rendent mercredi, séparément, '
#                 'dans des zones sinistrées, alors que les secouristes '
#                 'continuent de s’affairer pour tenter de retrouver des '
#                 'survivants.',
#  'image': 'https://img.lemde.fr/2024/10/01/0/0/8640/5760/110/73/60/0/7daa72d_893440dc634d46eb9526ab2f5675f496-1-1506dd3321a54caba8b703fd992d7e50.jpg',
#  'title': 'Ouragan Hélène : au moins 159 morts dans le sud-est des Etats-Unis '
#           '; Joe Biden doit se rendre en Caroline du Nord'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Le premier ministre a tenu des propos volontaristes sur '
#                 'l’urgence écologique lors de sa déclaration de politique '
#                 'générale, mardi 1ᵉʳ\xa0octobre, mais certaines de ses '
#                 'décisions laissent planer le doute sur ses intentions, '
#                 'notamment le périmètre rogné du ministère d’Agnès '
#                 'Pannier-Runacher.',
#  'image': 'https://img.lemde.fr/2024/10/01/0/0/5899/3933/110/73/60/0/f69a161_1727792455759-jmug240923094.jpg',
#  'title': 'Malgré des phrases fortes, Michel Barnier peine à dissiper les '
#           'inquiétudes autour de la planification écologique'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Le pétrolier français possède plusieurs licences '
#                 'd’exploration au large du Suriname.  «\xa0Ce projet phare est '
#                 'le premier développement offshore dans le pays\xa0», a '
#                 'souligné Patrick Pouyanné, PDG de TotalEnergies, alors que la '
#                 'production doit débuter en\xa02028.',
#  'image': 'https://img.lemde.fr/2024/10/01/0/0/5500/3666/110/73/60/0/6d15029_2024-10-01t160747z-1028088505-rc2lbaa471q0-rtrmadp-3-suriname-totalenergies.JPG',
#  'title': 'TotalEnergies va investir « environ 10,5 milliards de dollars » '
#           'dans des champs de pétrole et de gaz au Suriname'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Clotilde Bato et Mathieu Courgeau, coprésidents du Collectif '
#                 'Nourrir rappellent, dans une tribune au «\xa0Monde\xa0», que '
#                 'l’avenir est dans le pré, à condition de soutenir l’élevage '
#                 'paysan, alors que la nouvelle ministre de l’agriculture est '
#                 'attendue au Sommet de l’élevage, qui se tient à '
#                 'Clermont-Ferrand du 1ᵉʳau 4\xa0octobre',
#  'image': 'https://img.lemde.fr/2024/09/30/0/0/5568/3712/110/73/60/0/ea32c43_1727684826827-pns-777120058.jpg',
#  'title': 'Agriculture : « La concentration est un frein à l’engagement des '
#           'fermes dans la transition vers l’agroécologie »'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Chercheurs et responsables internationaux s’inquiètent du '
#                 'manque de communication de la part des autorités sanitaires '
#                 'américaines à la suite d’un premier cas humain sans aucun '
#                 'contact avéré avec un animal infecté dans l’Etat du Missouri.',
#  'image': 'https://img.lemde.fr/2024/09/27/61/0/3545/2363/110/73/60/0/1c21c9a_1727449395833-063-2150341567.jpg',
#  'title': 'Grippe aviaire : l’opacité de l’enquête américaine rend impossible '
#           'l’évaluation du risque'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'L’augmentation des «\xa0petites retraites\xa0» se concrétise. '
#                 'Et tandis que le prix repère du gaz repart à la hausse et que '
#                 'les aides personnalisées au logement sont revalorisées, le '
#                 'taux d’usure baisse à nouveau, pour les crédits immobiliers.',
#  'image': 'https://img.lemde.fr/2023/05/03/0/0/3000/2000/110/73/60/0/fbf8301_1683120136900-lmargent6.jpg',
#  'title': 'Ce qui change le 1ᵉʳ octobre : retraites, crédit immobilier, '
#           'stationnement des SUV, revenu de solidarité active, aides au '
#           'logement, gaz…'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Dans un rapport publié lundi 30\xa0septembre, l’institution '
#                 'déplore un «\xa0fossé\xa0» entre les «\xa0plans stratégiques '
#                 'nationaux\xa0», élaborés par chaque Etat pour attribuer '
#                 'certaines aides européennes, et les objectifs climatiques et '
#                 'environnementaux que s’est fixés l’UE.',
#  'image': 'https://img.lemde.fr/2024/09/30/0/0/5500/3666/110/73/60/0/0b2eced_1727705247050-043-dpa-pa-240411-99-644021-dpai.jpg',
#  'title': 'La PAC ne permet pas d’atteindre les objectifs du pacte vert, selon '
#           'la Cour des comptes européenne'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Les scientifiques sont sous pression pour mener la lutte '
#                 'contre le dérèglement climatique et alerter le grand public '
#                 'sur ses méfaits. Un engagement qui comporte parfois des '
#                 'risques.',
#  'image': 'https://img.lemde.fr/2024/09/24/0/111/3744/2496/110/73/60/0/8667f8f_1727187729611-fxcavm2xwaapmqhrec.jpg',
#  'title': 'Les chercheurs au secours de la planète'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Le déploiement de points d’eau sécurisés et une campagne de '
#                 'vaccination ont permis d’empêcher la multiplication des cas '
#                 'dans l’île. Mais la persistance de la maladie dans les '
#                 'Comores voisines empêche de baisser la garde.',
#  'image': 'https://img.lemde.fr/2024/09/27/0/0/8256/5504/110/73/60/0/476965d_1727445719071-000-34jc8rm.jpg',
#  'title': 'A Mayotte, l’épidémie de choléra jugulée par les autorités '
#           'sanitaires'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'L’interprofession France Bois Forêt conteste l’agrément '
#                 'octroyé à cette organisation au titre de la protection de '
#                 'l’environnement. Une démarche inédite révélatrice des '
#                 'tensions sur le sujet de la gestion forestière en France.',
#  'image': 'https://img.lemde.fr/2024/09/27/0/0/1500/1000/110/73/60/0/97fd4d2_1727447775589-sipa-01174497-000032.jpg',
#  'title': 'Canopée, l’association qui dérange les forestiers, dans le viseur '
#           'du secteur'}
# 2024-10-08 12:12:44 [scrapy.core.scraper] DEBUG: Scraped from <200 https://www.lemonde.fr/planete/>
# {'description': 'Un rapport de l’observatoire européen, publié lundi, rapporte '
#                 'que plus d’un cinquième de la surface océanique mondiale a '
#                 'connu une vague de chaleur sévère en\xa02023. Ce '
#                 'réchauffement s’explique par le fait que les océans ont '
#                 'absorbé depuis 1970 «\xa0plus de 90\xa0% de l’excès de '
#                 'chaleur du système climatique\xa0».',
#  'image': 'https://img.lemde.fr/2019/11/26/0/0/5314/3543/110/73/60/0/48dc102_dkS_mcEbunufJbcYAud1wrS3.jpg',
#  'title': 'Le rythme de réchauffement des océans a presque doublé depuis 2005, '
#           'selon Copernicus'}
# 2024-10-08 12:12:44 [scrapy.core.engine] INFO: Closing spider (finished)
# 2024-10-08 12:12:44 [scrapy.statscollectors] INFO: Dumping Scrapy stats:
# {'downloader/request_bytes': 7760,
#  'downloader/request_count': 30,
#  'downloader/request_method_count/GET': 30,
#  'downloader/response_bytes': 2545651,
#  'downloader/response_count': 30,
#  'downloader/response_status_count/200': 30,
#  'elapsed_time_seconds': 0.64308,
#  'finish_reason': 'finished',
#  'finish_time': datetime.datetime(2024, 10, 8, 10, 12, 44, 645472, tzinfo=datetime.timezone.utc),
#  'httpcompression/response_bytes': 10237156,
#  'httpcompression/response_count': 30,
#  'item_scraped_count': 1484,
#  'log_count/DEBUG': 1515,
#  'log_count/ERROR': 3,
#  'log_count/INFO': 10,
#  'log_count/WARNING': 1,
#  'memusage/max': 72810496,
#  'memusage/startup': 72810496,
#  'request_depth_max': 1,
#  'response_received_count': 30,
#  'robotstxt/request_count': 1,
#  'robotstxt/response_count': 1,
#  'robotstxt/response_status_count/200': 1,
#  'scheduler/dequeued': 29,
#  'scheduler/dequeued/memory': 29,
#  'scheduler/enqueued': 29,
#  'scheduler/enqueued/memory': 29,
#  'spider_exceptions/IndexError': 3,
#  'start_time': datetime.datetime(2024, 10, 8, 10, 12, 44, 2392, tzinfo=datetime.timezone.utc)}
# 2024-10-08 12:12:44 [scrapy.core.engine] INFO: Spider closed (finished)

# %% [markdown]
# ## Postprocessing
#
# Si l'on se réfère au diagramme d'architecture de Scrapy, on voit qu'il
# est possible d'insérer des composants supplémentaires dans le flux de
# traitement. Ces composants s'appellent `Pipelines`.
#
# Par défaut, tous les `Item` générés au sein d'un projet Scrapy passent
# par les `Pipelines`. Les pipelines sont utilisés la plupart du temps
# pour :
#
# -   Nettoyer du contenu HTML ;
# -   Valider les données scrapées ;
# -   Supprimer les items qu'on ne souhaite pas stocker ;
# -   Stocker ces objets dans des bases de données.
#
# Les pipelines doivent être définis dans le fichier `pipelines.py`.
#
# Dans notre cas, on peut vouloir nettoyer le champ `title` pour enlever
# les caractères superflus.
#
# Nous allons alors transferer la fonction de nettoyage du code html dans
# une Pipeline.

# %%
# %load newscrawler/newscrawler/pipelines.py

# Define your item pipelines here
#
# Don't forget to add your pipeline to the ITEM_PIPELINES setting
# See: https://docs.scrapy.org/en/latest/topics/item-pipeline.html

from scrapy.exceptions import DropItem


class TextPipeline(object):

    def process_item(self, item, spider):
        if item['title']:
            item["title"] = clean_spaces(item["title"])
            return item
        else:
            raise DropItem(f"Missing title in {item}")


def clean_spaces(string):
    if string:
        return " ".join(string.split())

# %% [markdown]
# Pour dire au process Scrapy de faire transiter les items par ces
# pipelines. Il faut le spécifier dans le fichier de paramétrage
# `settings.py`.

# %%
ITEM_PIPELINES = {
    'newscrawler.pipelines.TextPipeline': 300,
}

# %% [markdown]
# On peut maintenant supprimer la fonction `clean_spaces()` de
# l'extraction des données et laisser le Pipeline faire son travail. La
# valeur entière définie permet de déterminer l'ordre dans lequel les
# pipelines vont être appelés. Ces entiers peuvent être compris entre 0 et
# 1000.
#
# On relance notre spider :
# ```
# scrapy crawl lemondev4 -o ../data/articles.json
# ```

# %% [markdown]
# On peut aussi utiliser les Pipelines pour stocker les données récupérées
# dans une base de données.
#
# La prochaine partie du cours explique plus en détail le fonctionnement de Mongo, mais voici une bref introduction
#
# Pour stocker les items dans des documents mongo :

# %%
import pymongo


class MongoPipeline(object):
    collection_name = 'scrapy_items'

    def open_spider(self, spider):
        self.client = pymongo.MongoClient()
        self.db = self.client["lemonde"]

    def close_spider(self, spider):
        self.client.close()

    def process_item(self, item, spider):
        self.db[self.collection_name].insert_one(dict(item))
        return item

# %% [markdown]
# Ici on redéfinit deux autres méthodes: `open_spider()`et
# `close_spider()`, ces méthodes sont appelées comme leur nom l'indique,
# lorsque la Spider est instanciée et fermée.
#
# Ces méthodes nous permettent d'ouvrir la connexion Mongo et de la fermer
# lorsque le scraping se termine. La méthode `process_item()` est appelé à
# chaque fois qu'un item passe dans le mécanisme interne de scrapy. Ici,
# la méthode permet d'insérer l'item en tant que document mongo.
#
# Pour que ce pipeline soit appelé il faut l'ajouter dans les settings du
# projet.

# %%
ITEM_PIPELINES = {
    'newscrawler.pipelines.TextPipeline': 100,
    'newscrawler.pipelines.MongoPipeline': 300
}

# %% [markdown]
# Le pipeline est ajoutée à la fin du process pour profiter des deux
# précédents.

# %% [markdown]
# ## Settings
#
# Scrapy permet de gérer le comportement des spiders avec certains
# paramètres. Comme expliqué dans le premier cours, il est important de
# suivre des règles en respectant la structure des différents sites. Il
# existe énormément de paramètres mais nous allons (dans le cadre de ce
# cours) aborder les plus utilisés :
#
# -   DOWNLOAD\_DELAY : Le temps de téléchargement entre chaque requête
#     sur le même domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_DOMAIN : Nombre de requêtes simultanées
#     par domaine ;
# -   CONCURRENT\_REQUESTS\_PER\_IP : Nombre de requêtes simultanées par
#     IP ;
# -   DEFAULT\_REQUEST\_HEADERS : Headers HTTP utilisés pour les requêtes
#     ;
# -   ROBOTSTXT\_OBEY : Scrapy récupère le robots.txt et adapte le
#     scraping en fonction des règles trouvées ;
# -   USER\_AGENT : UserAgent utilisé pour faire les requêtes ;
# -   BOT\_NAME : Nom du bot annoncé lors des requêtes
# -   HTTPCACHE\_ENABLED : Utilisation du cache HTTP, utile lors du
#     parcours multiple de la même page.
#
# Le fichiers `settings.py` permet de définir les paramètres globaux d'un
# projet. Si votre projet contient un grand nombre de spiders, il peut
# être intéressant d'avoir des paramètres distincts pour chaque spider. Un
# moyen simple est d'ajouter un attribut `custom_settings` à votre spider
# :

# %%
class LeMondeSpider(scrapy.Spider):
    name = "lemonde"
    allowed_domains = ["lemonde.fr"]
    start_urls = ['http://lemonde.fr/']
    custom_settings = {
        "HTTPCACHE_ENABLED": True,
        "CONCURRENT_REQUESTS_PER_DOMAIN": 100
    }

# %% [markdown]
# C'est la fin de l'introduction à Scrapy. Vous pouvez passer à la suite `3Mongo`
